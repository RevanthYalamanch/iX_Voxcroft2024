# %%
import pandas as pd
import numpy as np

#read in the dataset with the new columns given to us
df = pd.read_excel('/Users/mollyrudisill/Voxcroft/new_data.xlsx')

#create a new empty dataset to add
df_new = pd.DataFrame(columns=df.columns)
#the column with the name or entity name
df_new.rename(columns={'Article_Content_People_AI_Model': 'Name'}, inplace=True)
#the type, either people or entity
df_new.rename(columns={'Article_Content_Entities_AI_Model': 'Identity_Type'}, inplace=True)
#new column with the position of the name relative to the others in the article
df_new['Position'] = np.nan

# %%
df
# Out:
#       Article_Date_Published  \
# 0        2024-06-11 07:34:17
# 1        2024-06-11 05:10:00
# 2        2024-06-11 05:00:00
# 3        2024-06-11 04:52:05
# 4        2024-06-11 04:40:00
# ...                      ...
# 40229    2024-05-12 09:17:42
# 40230    2024-05-12 09:17:35
# 40231    2024-05-12 09:17:03
# 40232    2024-05-12 09:17:01
# 40233    2024-05-12 09:13:34
#
#                                             Article_Body  \
# 0      Reading Time: 3 minutes\nIsrael’s parliament m...
# 1      ANC’s aggrieved PEC members draw a line in the...
# 2      Daily news update: Axed MK founder alone at Pa...
# 3      Search continues for plane carrying Malawi VP ...
# 4      Axing corrupt Tshwane cops: ‘more action neede...
# ...                                                  ...
# 40229  How about some marketing lessons from Nando’s,...
# 40230  Many say the rate of crime in KwaZulu-Natal is...
# 40231  According to the Gauteng Health Department, a ...
# 40232  SuerSport United coach Gavin Hunt at the Harry...
# 40233  A mother from rural Limpopo successfully turne...
#
#                          Article_Content_People_AI_Model  \
# 0      [Benny Gantz, Benjamin Netanyahu, Yoav Gallant...
# 1      [Mathabatha, Stan Mathabatha, Reuben Madadzhe,...
# 2      [Axed MK, Jabulani Khumalo, Ajay Gupta, Lethab...
# 3      [Saulos Chilima, Saulos Klaus, Saulos Klaus, V...
# 4      [Axing, Nigel Sibanda/, Grandi Theunissen, Jac...
# ...                                                  ...
# 40229  Baas John|John Steenhuisen|Steenhuisen|John Vu...
# 40230                                                NaN
# 40231                                                NaN
# 40232  Gavin Hunt|@officialPSL/X|Kegan Johannes|Gavin...
# 40233  Ekaterina Bolovtsova|Lina Baloyi|Maake Kganyag...
#
#                        Article_Content_Entities_AI_Model       Article_Source  \
# 0      [Knesset, Gantz, Defence, Gantz, Resented, the...         sabcnews.com
# 1      [ANC, PEC, Limpopo ANC, ANC, PEC, the Electora...        citizen.co.za
# 2      [Parliament ,  SA, ,  Court, Ace’s, WeSizwe pa...        citizen.co.za
# 3      [Office of the President, Cabinet, the Malawi ...        citizen.co.za
# 4      [TMPD, Department, Tshwane Metro Police Depart...        citizen.co.za
# ...                                                  ...                  ...
# 40229                            Nando|Nando|Nando|Nando    sundayworld.co.za
# 40230                                                NaN          twitter.com
# 40231  the Gauteng Health Department|Bertha Gxowa Hos...      surgezirc.co.za
# 40232  SuerSport|Orlando Pirates|Orlando Pirates|Supe...  thesouthafrican.com
# 40233  the Road Accident Fund|Pexels|MOTHER|the Road ...            dfa.co.za
#
#                     Voice                            Article_Themes_AI_Model  \
# 0                     NaN  [Primary: Conflict, war and peace|92% |Seconda...
# 1      Alex Japho Matlala  [Primary: Society|67% |Secondary: Uncategorize...
# 2           Nicholas Zaal  [Primary: Economy, business and finance|51% |S...
# 3            Faizel Patel  [Primary: Politics|52% |Secondary: Uncategoriz...
# 4         Marizka Coetzer  [Primary: Crime, law and justice|100% |Seconda...
# ...                   ...                                                ...
# 40229                 NaN  [Primary: Arts, culture, entertainment and med...
# 40230      Yusuf Abramjee  [Primary: Crime, law and justice|97% |Secondar...
# 40231                 NaN  [Primary: Health|98% |Secondary: Uncategorized...
# 40232       Siseko Gwegwe  [Primary: Human interest|56% |Secondary: Uncat...
# 40233        Zelda Venter  [Primary: Society|100% |Secondary: Communities...
#
#         Article_Subject_Keyword_Identified  \
# 0                                      NaN
# 1                                      ANC
# 2      Cape Town|Johannesburg|South Africa
# 3                                      NaN
# 4                             South Africa
# ...                                    ...
# 40229                  DA|John Steenhuisen
# 40230                                  NaN
# 40231               Cape Town|South Africa
# 40232               Cape Town|South Africa
# 40233                         South Africa
#
#                         Article_Topic_Keyword_Identified
# 0        Armed Conflict|Crime & Terrorism|State Security
# 1                                                    NaN
# 2      Armed Conflict|Civil Unrest & Protest|Crime & ...
# 3                                         State Security
# 4                       Crime & Terrorism|State Security
# ...                                                  ...
# 40229                                                NaN
# 40230                   Crime & Terrorism|State Security
# 40231                                                NaN
# 40232                                                NaN
# 40233                                Leadership delivery
#
# [40234 rows x 9 columns]

# %%
#create a subset of the data - this is what to change to use other parts of the dataset
subset = df[:1000]

# %%
#separate the strings into arrays
for num in range(len(subset)):
    subset.at[num, 'Article_Content_People_AI_Model'] = str(subset['Article_Content_People_AI_Model'][num]).split("|")
    subset.at[num, 'Article_Content_Entities_AI_Model'] = str(subset['Article_Content_Entities_AI_Model'][num]).split("|")

# %%
#add the people names
newdf_counter = 0
olddf_counter = -1
for entry in subset['Article_Content_People_AI_Model']:
    olddf_counter+=1
    position_counter = 0
    for word in entry:
        df_new.loc[newdf_counter, 'Name'] = word
        df_new.loc[newdf_counter, 'Identity_Type'] = 'People'
        df_new.loc[newdf_counter, 'Position'] = position_counter
        df_new.loc[newdf_counter, 'Article_Date_Published'] = subset.loc[olddf_counter, 'Article_Date_Published']
        df_new.loc[newdf_counter, 'Article_Body'] = subset.loc[olddf_counter, 'Article_Body']
        df_new.loc[newdf_counter, 'Article_Source'] = subset.loc[olddf_counter, 'Article_Source']
        df_new.loc[newdf_counter, 'Voice'] = subset.loc[olddf_counter, 'Voice']
        df_new.loc[newdf_counter, 'Article_Themes_AI_Model'] = subset.loc[olddf_counter, 'Article_Themes_AI_Model']
        df_new.loc[newdf_counter, 'Article_Subject_Keyword_Identified'] = subset.loc[olddf_counter, 'Article_Subject_Keyword_Identified']
        df_new.loc[newdf_counter, 'Article_Topic_Keyword_Identified'] = subset.loc[olddf_counter, 'Article_Topic_Keyword_Identified']
        newdf_counter+=1
        position_counter+=1

# %%
#add the entity names
newdf_counter = len(df_new)
olddf_counter = -1
for entry in subset['Article_Content_Entities_AI_Model']:
    olddf_counter+=1
    position_counter = 0
    for word in entry:
        df_new.loc[newdf_counter, 'Name'] = word
        df_new.loc[newdf_counter, 'Identity_Type'] = 'Entity'
        df_new.loc[newdf_counter, 'Position'] = position_counter
        df_new.loc[newdf_counter, 'Article_Date_Published'] = subset.loc[olddf_counter, 'Article_Date_Published']
        df_new.loc[newdf_counter, 'Article_Body'] = subset.loc[olddf_counter, 'Article_Body']
        df_new.loc[newdf_counter, 'Article_Source'] = subset.loc[olddf_counter, 'Article_Source']
        df_new.loc[newdf_counter, 'Voice'] = subset.loc[olddf_counter, 'Voice']
        df_new.loc[newdf_counter, 'Article_Themes_AI_Model'] = subset.loc[olddf_counter, 'Article_Themes_AI_Model']
        df_new.loc[newdf_counter, 'Article_Subject_Keyword_Identified'] = subset.loc[olddf_counter, 'Article_Subject_Keyword_Identified']
        df_new.loc[newdf_counter, 'Article_Topic_Keyword_Identified'] = subset.loc[olddf_counter, 'Article_Topic_Keyword_Identified']
        newdf_counter+=1
        position_counter+=1

# %%
df_new.head(30)
# Out:
#    Article_Date_Published                                       Article_Body  \
# 0     2024-06-11 07:34:17  Reading Time: 3 minutes\nIsrael’s parliament m...
# 1     2024-06-11 07:34:17  Reading Time: 3 minutes\nIsrael’s parliament m...
# 2     2024-06-11 07:34:17  Reading Time: 3 minutes\nIsrael’s parliament m...
# 3     2024-06-11 07:34:17  Reading Time: 3 minutes\nIsrael’s parliament m...
# 4     2024-06-11 07:34:17  Reading Time: 3 minutes\nIsrael’s parliament m...
# 5     2024-06-11 07:34:17  Reading Time: 3 minutes\nIsrael’s parliament m...
# 6     2024-06-11 07:34:17  Reading Time: 3 minutes\nIsrael’s parliament m...
# 7     2024-06-11 07:34:17  Reading Time: 3 minutes\nIsrael’s parliament m...
# 8     2024-06-11 07:34:17  Reading Time: 3 minutes\nIsrael’s parliament m...
# 9     2024-06-11 05:10:00  ANC’s aggrieved PEC members draw a line in the...
# 10    2024-06-11 05:10:00  ANC’s aggrieved PEC members draw a line in the...
# 11    2024-06-11 05:10:00  ANC’s aggrieved PEC members draw a line in the...
# 12    2024-06-11 05:10:00  ANC’s aggrieved PEC members draw a line in the...
# 13    2024-06-11 05:10:00  ANC’s aggrieved PEC members draw a line in the...
# 14    2024-06-11 05:10:00  ANC’s aggrieved PEC members draw a line in the...
# 15    2024-06-11 05:10:00  ANC’s aggrieved PEC members draw a line in the...
# 16    2024-06-11 05:10:00  ANC’s aggrieved PEC members draw a line in the...
# 17    2024-06-11 05:10:00  ANC’s aggrieved PEC members draw a line in the...
# 18    2024-06-11 05:00:00  Daily news update: Axed MK founder alone at Pa...
# 19    2024-06-11 05:00:00  Daily news update: Axed MK founder alone at Pa...
# 20    2024-06-11 05:00:00  Daily news update: Axed MK founder alone at Pa...
# 21    2024-06-11 05:00:00  Daily news update: Axed MK founder alone at Pa...
# 22    2024-06-11 05:00:00  Daily news update: Axed MK founder alone at Pa...
# 23    2024-06-11 05:00:00  Daily news update: Axed MK founder alone at Pa...
# 24    2024-06-11 05:00:00  Daily news update: Axed MK founder alone at Pa...
# 25    2024-06-11 05:00:00  Daily news update: Axed MK founder alone at Pa...
# 26    2024-06-11 05:00:00  Daily news update: Axed MK founder alone at Pa...
# 27    2024-06-11 05:00:00  Daily news update: Axed MK founder alone at Pa...
# 28    2024-06-11 05:00:00  Daily news update: Axed MK founder alone at Pa...
# 29    2024-06-11 05:00:00  Daily news update: Axed MK founder alone at Pa...
#
#                   Name Identity_Type Article_Source               Voice  \
# 0          Benny Gantz        People   sabcnews.com                 NaN
# 1   Benjamin Netanyahu        People   sabcnews.com                 NaN
# 2         Yoav Gallant        People   sabcnews.com                 NaN
# 3        Gadi Eisenkot        People   sabcnews.com                 NaN
# 4     Bezalel Smotrich        People   sabcnews.com                 NaN
# 5        Assaf Shapira        People   sabcnews.com                 NaN
# 6          Inbal Tzach        People   sabcnews.com                 NaN
# 7           Tal Shoham        People   sabcnews.com                 NaN
# 8             Smotrich        People   sabcnews.com                 NaN
# 9           Mathabatha        People  citizen.co.za  Alex Japho Matlala
# 10     Stan Mathabatha        People  citizen.co.za  Alex Japho Matlala
# 11     Reuben Madadzhe        People  citizen.co.za  Alex Japho Matlala
# 12    Reggie Molokomme        People  citizen.co.za  Alex Japho Matlala
# 13        Danny Ndlovu        People  citizen.co.za  Alex Japho Matlala
# 14       Frans Mokwele        People  citizen.co.za  Alex Japho Matlala
# 15     Rosemary Molepo        People  citizen.co.za  Alex Japho Matlala
# 16    Jeremiah Ngobeni        People  citizen.co.za  Alex Japho Matlala
# 17       Jimmy Machaka        People  citizen.co.za  Alex Japho Matlala
# 18             Axed MK        People  citizen.co.za       Nicholas Zaal
# 19    Jabulani Khumalo        People  citizen.co.za       Nicholas Zaal
# 20          Ajay Gupta        People  citizen.co.za       Nicholas Zaal
# 21       Lethabo Lejoy        People  citizen.co.za       Nicholas Zaal
# 22       Christall Kay        People  citizen.co.za       Nicholas Zaal
# 23    Jabulani Khumalo        People  citizen.co.za       Nicholas Zaal
# 24    Jabulani Khumalo        People  citizen.co.za       Nicholas Zaal
# 25    Jabulani Khumalo        People  citizen.co.za       Nicholas Zaal
# 26          Jacob Zuma        People  citizen.co.za       Nicholas Zaal
# 27          Jacob Zuma        People  citizen.co.za       Nicholas Zaal
# 28             Khumalo        People  citizen.co.za       Nicholas Zaal
# 29       Raymond Zondo        People  citizen.co.za       Nicholas Zaal
#
#                               Article_Themes_AI_Model  \
# 0   [Primary: Conflict, war and peace|92% |Seconda...
# 1   [Primary: Conflict, war and peace|92% |Seconda...
# 2   [Primary: Conflict, war and peace|92% |Seconda...
# 3   [Primary: Conflict, war and peace|92% |Seconda...
# 4   [Primary: Conflict, war and peace|92% |Seconda...
# 5   [Primary: Conflict, war and peace|92% |Seconda...
# 6   [Primary: Conflict, war and peace|92% |Seconda...
# 7   [Primary: Conflict, war and peace|92% |Seconda...
# 8   [Primary: Conflict, war and peace|92% |Seconda...
# 9   [Primary: Society|67% |Secondary: Uncategorize...
# 10  [Primary: Society|67% |Secondary: Uncategorize...
# 11  [Primary: Society|67% |Secondary: Uncategorize...
# 12  [Primary: Society|67% |Secondary: Uncategorize...
# 13  [Primary: Society|67% |Secondary: Uncategorize...
# 14  [Primary: Society|67% |Secondary: Uncategorize...
# 15  [Primary: Society|67% |Secondary: Uncategorize...
# 16  [Primary: Society|67% |Secondary: Uncategorize...
# 17  [Primary: Society|67% |Secondary: Uncategorize...
# 18  [Primary: Economy, business and finance|51% |S...
# 19  [Primary: Economy, business and finance|51% |S...
# 20  [Primary: Economy, business and finance|51% |S...
# 21  [Primary: Economy, business and finance|51% |S...
# 22  [Primary: Economy, business and finance|51% |S...
# 23  [Primary: Economy, business and finance|51% |S...
# 24  [Primary: Economy, business and finance|51% |S...
# 25  [Primary: Economy, business and finance|51% |S...
# 26  [Primary: Economy, business and finance|51% |S...
# 27  [Primary: Economy, business and finance|51% |S...
# 28  [Primary: Economy, business and finance|51% |S...
# 29  [Primary: Economy, business and finance|51% |S...
#
#      Article_Subject_Keyword_Identified  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   ANC
# 10                                  ANC
# 11                                  ANC
# 12                                  ANC
# 13                                  ANC
# 14                                  ANC
# 15                                  ANC
# 16                                  ANC
# 17                                  ANC
# 18  Cape Town|Johannesburg|South Africa
# 19  Cape Town|Johannesburg|South Africa
# 20  Cape Town|Johannesburg|South Africa
# 21  Cape Town|Johannesburg|South Africa
# 22  Cape Town|Johannesburg|South Africa
# 23  Cape Town|Johannesburg|South Africa
# 24  Cape Town|Johannesburg|South Africa
# 25  Cape Town|Johannesburg|South Africa
# 26  Cape Town|Johannesburg|South Africa
# 27  Cape Town|Johannesburg|South Africa
# 28  Cape Town|Johannesburg|South Africa
# 29  Cape Town|Johannesburg|South Africa
#
#                      Article_Topic_Keyword_Identified  Position
# 0     Armed Conflict|Crime & Terrorism|State Security       0.0
# 1     Armed Conflict|Crime & Terrorism|State Security       1.0
# 2     Armed Conflict|Crime & Terrorism|State Security       2.0
# 3     Armed Conflict|Crime & Terrorism|State Security       3.0
# 4     Armed Conflict|Crime & Terrorism|State Security       4.0
# 5     Armed Conflict|Crime & Terrorism|State Security       5.0
# 6     Armed Conflict|Crime & Terrorism|State Security       6.0
# 7     Armed Conflict|Crime & Terrorism|State Security       7.0
# 8     Armed Conflict|Crime & Terrorism|State Security       8.0
# 9                                                 NaN       0.0
# 10                                                NaN       1.0
# 11                                                NaN       2.0
# 12                                                NaN       3.0
# 13                                                NaN       4.0
# 14                                                NaN       5.0
# 15                                                NaN       6.0
# 16                                                NaN       7.0
# 17                                                NaN       8.0
# 18  Armed Conflict|Civil Unrest & Protest|Crime & ...       0.0
# 19  Armed Conflict|Civil Unrest & Protest|Crime & ...       1.0
# 20  Armed Conflict|Civil Unrest & Protest|Crime & ...       2.0
# 21  Armed Conflict|Civil Unrest & Protest|Crime & ...       3.0
# 22  Armed Conflict|Civil Unrest & Protest|Crime & ...       4.0
# 23  Armed Conflict|Civil Unrest & Protest|Crime & ...       5.0
# 24  Armed Conflict|Civil Unrest & Protest|Crime & ...       6.0
# 25  Armed Conflict|Civil Unrest & Protest|Crime & ...       7.0
# 26  Armed Conflict|Civil Unrest & Protest|Crime & ...       8.0
# 27  Armed Conflict|Civil Unrest & Protest|Crime & ...       9.0
# 28  Armed Conflict|Civil Unrest & Protest|Crime & ...      10.0
# 29  Armed Conflict|Civil Unrest & Protest|Crime & ...      11.0

# %%
df_new.to_csv('data_processed.csv')
