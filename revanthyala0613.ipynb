# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# Load the dataset
data = pd.read_csv('20240611_GF SA Safety_Last30Days.csv', nrows = 200)

# Define a simple stopwords list
simple_stopwords = set([
    'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
    'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself',
    'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which',
    'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be',
    'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an',
    'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by',
    'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before',
    'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over',
    'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why',
    'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no',
    'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will',
    'just', 'don', 'should', 'now'
])

# Preprocessing function without NLTK
def preprocess_text_simple(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()  # Lowercase
    text = re.sub(r'\d+', '', text)  # Remove digits
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    words = text.split()
    words = [word for word in words if word not in simple_stopwords]  # Remove stopwords
    return ' '.join(words)

# Apply preprocessing to the Article_Body column
data['Processed_Article_Body'] = data['Article_Body'].apply(preprocess_text_simple)

# Initialize the TF-IDF vectorizer with a maximum number of features
vectorizer = TfidfVectorizer(max_features=1000)

# Fit and transform the processed article body text
tfidf_matrix = vectorizer.fit_transform(data['Processed_Article_Body'])

# Convert the TF-IDF matrix to a DataFrame for better readability
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

# Save the TF-IDF DataFrame to a CSV file
tfidf_df.to_csv('tfidf_analysis_results.csv', index=False)

# Function to get the top N terms with the highest TF-IDF scores
def get_top_n_terms(tfidf_matrix, feature_names, top_n=10):
    summed_tfidf = tfidf_matrix.sum(axis=0)
    sorted_indices = np.argsort(summed_tfidf)[::-1][:top_n]
    top_terms = [(feature_names[i], summed_tfidf[0, i]) for i in sorted_indices]
    return top_terms

# Get the feature names
feature_names = vectorizer.get_feature_names_out()

# Get the top 20 terms across all documents
top_terms = get_top_n_terms(tfidf_matrix, feature_names, top_n=20)

# Print the top terms
for term, score in top_terms:
     print(f"Term: {term}, Score: {score[0,0]:.4f}")
# Out:
# Term: [['models' 'model' 'funding' 'tax' 'organisation' 'netanyahu' 'europe'
#   'unlikely' 'using' 'attacks' 'rights' 'publishers' 'network' 'ranked'
#   'perhaps' 'early' 'implementing' 'tech' 'fresh' 'debate' 'production'
#   'pressure' 'society' 'try' 'prison' 'fall' 'consequences' 'un' 'hold'
#   'happened' 'agree' 'idea' 'something' 'benefits' 'means' 'success'
#   'conduct' 'everyone' 'jobs' 'crucial' 'recent' 'research' 'trip'
#   'released' 'democracy' 'complaint' 'apartheid' 'lerato' 'legislation'
#   'great' 'towards' 'feel' 'critical' 'wide' 'zverev' 'lot' 'follow'
#   'durban' 'director' 'opposition' 'experienced' 'gantz' 'sacp'
#   'includes' 'special' 'approach' 'allow' 'immediately' 'believe' 'via'
#   'gumede' 'comes' 'trade' 'russian' 'accommodation' 'anything' 'smaller'
#   'august' 'fully' 'illegal' 'company' 'brazil' 'sentence' 'legislature'
#   'half' 'size' 'little' 'offence' 'ten' 'impact' 'offers' 'served'
#   'instead' 'change' 'hope' 'outside' 'campaign' 'highest' 'stop'
#   'create' 'contempt' 'true' 'hard' 'numbers' 'goes' 'administration'
#   'anyone' 'likely' 'biden' 'weekend' 'speaking' 'done' 'option' 'mw'
#   'therefore' 'biggest' 'order' 'private' 'release' 'dm' 'india'
#   'alliance' 'serve' 'opened' 'committee' 'content' 'named' 'gauteng'
#   'situation' 'reach' 'low' 'records' 'required' 'ways' 'son' 'warriors'
#   'regulations' 'turned' 'arrangements' 'ensuring' 'person' 'longer'
#   'raymond' 'kaizer' 'emirates' 'main' 'rate' 'september' 'leave' 'began'
#   'aware' 'maverick' 'needed' 'young' 'maintenance' 'partners' 'billion'
#   'withdrawal' 'best' 'removed' 'twitter' 'port' 'field' 'meet' 'sparked'
#   'player' 'wesizwe' 'revenue' 'difficult' 'springbok' 'better' 'sound'
#   'guns' 'declared' 'environment' 'especially' 'join' 'kept' 'leinster'
#   'transnet' 'kzn' 'line' 'opportunity' 'operation' 'alleged' 'koko'
#   'keep' 'prime' 'mangena' 'event' 'iol' 'didn' 'nec' 'term' 'positive'
#   'infrastructure' 'ex' 'costs' 'night' 'groups' 'causing' 'photo'
#   'defence' 'equipment' 'residents' 'dropped' 'shedding' 'mentality'
#   'matches' 'marriage' 'behaviour' 'convicted' 'advertising' 'air'
#   'umkhonto' 'babies' 'labour' 'single' 'commission' 'tuesday' 'partner'
#   'charge' 'julius' 'save' 'tourism' 'today' 'name' 'freedom' 'gestures'
#   'average' 'leaders' 'point' 'suicide' 'junior' 'quarter' 'talks'
#   'handed' 'amunyela' 'remain' 'master' 'put' 'forward' 'career' 'food'
#   'interest' 'session' 'bpo' 'playing' 'decades' 'recovery' 'bring'
#   'taken' 'jail' 'efforts' 'israeli' 'cut' 'kilometre' 'black' 'picked'
#   'iec' 'claimed' 'scheduled' 'fighting' 'injuries' 'alongside'
#   'available' 'crisis' 'innings' 'games' 'cancer' 'proposal' 'province'
#   'facing' 'move' 'daily' 'rest' 'controversial' 'documents' 'table'
#   'processes' 'deliver' 'page' 'established' 'think' 'challenges'
#   'fossil' 'whose' 'victory' 'eight' 'posted' 'peace' 'thus' 'father'
#   'molefe' 'sibusiso' 'hostages' 'winter' 'votes' 'short' 'ports'
#   'significant' 'spain' 'spanish' 'terms' 'whether' 'image' 'morning'
#   'laconco' 'delivered' 'often' 'mother' 'fuel' 'potential' 'progressive'
#   'interdict' 'human' 'opening' 'squad' 'secretary' 'followed' 'weeks'
#   'outgoing' 'ball' 'previous' 'march' 'across' 'passing' 'effective'
#   'share' 'prevent' 'thought' 'subscribe' 'summit' 'reality'
#   'development' 'rules' 'christall' 'polls' 'economy' 'looking' 'problem'
#   'democratic' 'judge' 'history' 'particularly' 'cyril' 'continues' 'amg'
#   'resolution' 'inspired' 'netizens' 'official' 'previously' 'lead'
#   'rugby' 'used' 'wicket' 'sulfur' 'fifth' 'later' 'married' 'looked'
#   'april' 'advantage' 'late' 'nonku' 'benni' 'really' 'allegations'
#   'strong' 'heard' 'different' 'started' 'project' 'close' 'period' 'ifp'
#   'front' 'live' 'though' 'birds' 'alcaraz' 'race' 'meanwhile' 'bad'
#   'chiefs' 'away' 'driving' 'bester' 'mzansi' 'executive' 'north'
#   'reduce' 'want' 'past' 'lilongwe' 'deal' 'confidence' 'ended' 'july'
#   'trying' 'states' 'quality' 'ruling' 'dismissed' 'loss' 'series'
#   'foreign' 'least' 'championship' 'land' 'posts' 'needs' 'ago'
#   'appeared' 'mzuzu' 'current' 'step' 'urban' 'key' 'stormers' 'less'
#   'plan' 'saying' 'win' 'third' 'threat' 'revealed' 'deputy' 'customers'
#   'lethabo' 'total' 'dhl' 'attack' 'letter' 'family' 'balls' 'help'
#   'happy' 'reportedly' 'fire' 'criminal' 'consumers' 'breath' 'images'
#   'action' 'racism' 'nine' 'ordinary' 'post' 'npa' 'increase' 'big'
#   'nothing' 'issues' 'accident' 'winner' 'earlier' 'position' 'affected'
#   'held' 'zimbabwe' 'stated' 'ensure' 'completed' 'give' 'bill'
#   'management' 'turn' 'tournament' 'men' 'missing' 'industry' 'london'
#   'list' 'latest' 'rescue' 'insults' 'denny' 'miller' 'nigeria' 'full'
#   'sars' 'pitori' 'car' 'contact' 'possible' 'gupta' 'systems' 'days'
#   'ceo' 'sent' 'showed' 'lost' 'km' 'singer' 'brics' 'eskom' 'hike'
#   'school' 'premier' 'involved' 'supply' 'operations' 'test' 'section'
#   'khumalo' 'although' 'wife' 'reports' 'ground' 'result' 'died' 'expert'
#   'pa' 'cup' 'decision' 'capacity' 'came' 'abuse' 'arrested'
#   'consumption' 'play' 'limpopo' 'need' 'airport' 'skhothane' 'capital'
#   'centre' 'november' 'areas' 'offer' 'conference' 'working' 'growth'
#   'message' 'became' 'authorities' 'added' 'malema' 'near' 'start'
#   'address' 'finance' 'might' 'claims' 'relationship' 'non' 'things'
#   'general' 'range' 'able' 'despite' 'body' 'parliamentary' 'training'
#   'york' 'yet' 'spokesperson' 'viral' 'making' 'carrying' 'winning'
#   'couple' 'include' 'game' 'due' 'meeting' 'ireland' 'klaasen' 'pm'
#   'sharks' 'job' 'gave' 'intelligence' 'hollywoodbets' 'results' 'vs'
#   'number' 'wants' 'broos' 'open' 'popular' 'seven' 'board' 'saulos'
#   'taking' 'based' 'failed' 'zondo' 'points' 'award' 'force' 'officials'
#   'within' 'picture' 'october' 'enough' 'going' 'almost' 'date'
#   'independent' 'wickets' 'love' 'energy' 'say' 'six' 'ukraine' 'end'
#   'speaker' 'stage' 'vice' 'online' 'let' 'attend' 'show' 'months' 'know'
#   'legal' 'la' 'top' 'liga' 'sector' 'level' 'among' 'always' 'steyn'
#   'recently' 'nation' 'vote' 'major' 'saw' 'currently' 'aid' 'united'
#   'council' 'wrote' 'fight' 'ceasefire' 'european' 'johannesburg' 'get'
#   'markram' 'rule' 'global' 'confirmed' 'lebo' 'seats' 'together' 'trail'
#   'led' 'medical' 'use' 'cabinet' 'market' 'known' 'de' 'second' 'voters'
#   'leadership' 'find' 'final' 'football' 'jacob' 'vinicius' 'valencia'
#   'khayelitsha' 'others' 'demand' 'season' 'politics' 'middendorp' 'come'
#   'asked' 'companies' 'given' 'economic' 'birthday' 'countries' 'place'
#   'shows' 'form' 'law' 'marathon' 'called' 'seen' 'video' 'fraud' 'club'
#   'women' 'white' 'announced' 'even' 'health' 'kg' 'look' 'price' 'work'
#   'actress' 'gun' 'gosiame' 'maharaj' 'long' 'security' 'negotiations'
#   'much' 'watch' 'present' 'problems' 'publication' 'won' 'comrades'
#   'players' 'system' 'russia' 'husband' 'pretoria' 'challenge' 'military'
#   'ahead' 'received' 'elected' 'never' 'electricity' 're' 'ministers'
#   'constitutional' 'make' 'children' 'injured' 'century' 'proteas'
#   'cannot' 'went' 'another' 'face' 'timeslive' 'process' 'agreement'
#   'tshwane' 'shared' 'seat' 'local' 'expected' 'record' 'provincial'
#   'chief' 'daughter' 'microphone' 'businesslive' 'old' 'search' 've'
#   'subscription' 'played' 'continue' 'gaza' 'found' 'head' 'reported'
#   'following' 'killed' 'bulls' 'instagram' 'chakwera' 'performance' 'al'
#   'home' 'sithole' 'member' 'leader' 'bafana' 'per' 'become' 'way'
#   'public' 'community' 'holdings' 'justice' 'israel' 'several' 'arena'
#   'return' 'still' 'mail' 'trial' 'spurs' 'published' 'part' 'including'
#   'friday' 'week' 'mdluli' 'except' 'see' 'hospital' 'springboks'
#   'helpdesk' 'anytime' 'hamas' 'must' 'million' 'distributed' 'cancel'
#   'role' 'good' 'thursday' 'got' 'digital' 'woman' 'road' 'next'
#   'december' 'allegedly' 'dj' 'report' 'birth' 'corruption' 'beyond'
#   'plane' 'around' 'reduction' 'already' 'go' 'email' 'call' 'case'
#   'bangladesh' 'mps' 'unity' 'majority' 'racist' 'access' 'charges'
#   'fans' 'za' 'many' 'th' 'bid' 'take' 'financial' 'questions' 'matter'
#   'elections' 'state' 'africans' 'runs' 'war' 'mkp' 'attention' 'took'
#   'death' 'madrid' 'constitution' 'house' 'life' 'important' 'crime'
#   'well' 'hate' 'however' 'aircraft' 'five' 'western' 'group' 'coach'
#   'application' 'since' 'closed' 'star' 'man' 'january' 'saturday'
#   'journalism' 'every' 'times' 'far' 'stadium' 'set' 'high' 'sunday'
#   'right' 'statement' 'june' 'match' 'accused' 'minister' 'office'
#   'international' 'power' 'malawi' 'chilima' 'park' 'source' 'country'
#   'shebeshxt' 'service' 'team' 'without' 'four' 'told' 'left' 'according'
#   'business' 'election' 'african' 'tv' 'may' 'incident' 'real' 'gnu'
#   'privacy' 'cookies' 'personalise' 'cookie' 'manage' 'improve' 'month'
#   'three' 'uses' 'please' 'money' 'commenting' 'load' 'article' 'media'
#   'made' 'website' 'policies' 'quick' 'assembly' 'clear' 'world' 'policy'
#   'department' 'us' 'monday' 'influence' 'essential' 'sitting' 'vehicle'
#   'back' 'information' 'support' 'pay' 'run' 'parties' 'last' 'day' 'eff'
#   'social' 'former' 'years' 'briefly' 'members' 'reading' 'services' 'dr'
#   'town' 'year' 'sa' 'new' 'says' 'one' 'coalition' 'experience' 'time'
#   'city' 'could' 'police' 'free' 'zuma' 'also' 'court' 'two' 'parliament'
#   'ramaphosa' 'first' 'like' 'president' 'people' 'drive' 'mk' 'would'
#   'political' 'news' 'government' 'cape' 'comment' 'read' 'national'
#   'sign' 'party' 'africa' 'da' 'said' 'co' 'https' 'anc' 'south']], Score: 0.2052

# %%
# Out:
#     Article_Date_Published                                       Article_Body  \
# 0           6/11/2024 7:34  Reading Time: 3 minutes\nIsrael’s parliament m...
# 1           6/11/2024 5:10  ANC’s aggrieved PEC members draw a line in the...
# 2           6/11/2024 5:00  Daily news update: Axed MK founder alone at Pa...
# 3           6/11/2024 4:52  Search continues for plane carrying Malawi VP ...
# 4           6/11/2024 4:40  Axing corrupt Tshwane cops: ‘more action neede...
# ..                     ...                                                ...
# 195        6/10/2024 19:37  In a distressing development, a military aircr...
# 196        6/10/2024 19:35  The City of Tshwane says it will implement loa...
# 197        6/10/2024 19:35  Chief justice Raymond Zondo has declared June ...
# 198        6/10/2024 19:32  The Department of Transport says it is on trac...
# 199        6/10/2024 19:31  Economic Freedom Fighters (EFF) leader Julius ...
#
#                        Article_Content_People_AI_Model  \
# 0    Benny Gantz|Benjamin Netanyahu|Yoav Gallant|Ga...
# 1    Mathabatha|Stan Mathabatha|Reuben Madadzhe|Reg...
# 2    Axed MK|Jabulani Khumalo|Ajay Gupta|Lethabo Le...
# 3    Saulos Chilima|Saulos Klaus|Saulos Klaus|Valen...
# 4    Axing|Nigel Sibanda/|Grandi Theunissen|Jaco Ba...
# ..                                                 ...
# 195  Saulos Chilima|Saulos Chilima|Lazarus Chakwera...
# 196                 Lindela Mashigo|eNCA|Lehakwe Tlali
# 197                                Raymond Zondo|Zondo
# 198             Gemalto Altron Fintech Southern Africa
# 199  Julius Malema|Twerka|Julius Malema|Julius Male...
#
#                      Article_Content_Entities_AI_Model      Article_Source  \
# 0    Knesset|Gantz|Defence|Gantz|Resented|the Israe...        sabcnews.com
# 1    ANC|PEC|Limpopo ANC|ANC|PEC|the Electoral Comm...       citizen.co.za
# 2    Parliament | SA|| Court|Ace’s|WeSizwe party|MK...       citizen.co.za
# 3    Office of the President|Cabinet|the Malawi Def...       citizen.co.za
# 4    TMPD|Department|Tshwane Metro Police Departmen...       citizen.co.za
# ..                                                 ...                 ...
# 195                               Malawi Defense Force     surgezirc.co.za
# 196                                Soweto Gospel Choir       news365.co.za
# 197  the National Assembly|the National Council of ...  businesslive.co.za
# 198  The Department of Transport|Cabinet|SCM|Corpor...     economy24.co.za
# 199  EFF|Shebeshxt|Shebeshxt|Briefly TV Life|Shebes...       briefly.co.za
#
#                   Voice                            Article_Themes_AI_Model  \
# 0                   NaN  [Primary: Conflict, war and peace|92% |Seconda...
# 1    Alex Japho Matlala  [Primary: Society|67% |Secondary: Uncategorize...
# 2         Nicholas Zaal  [Primary: Economy, business and finance|51% |S...
# 3          Faizel Patel  [Primary: Politics|52% |Secondary: Uncategoriz...
# 4       Marizka Coetzer  [Primary: Crime, law and justice|100% |Seconda...
# ..                  ...                                                ...
# 195                 NaN  [Primary: Politics|80% |Secondary: Uncategoriz...
# 196        Nelly Ndlovu  [Primary: Economy, business and finance|95% |S...
# 197                 NaN  [Primary: Politics|94% |Secondary: Government ...
# 198                 NaN  [Primary: Economy, business and finance|82% |S...
# 199       Jessica Gcaba  [Primary: Disaster, accident and emergency inc...
#
#       Article_Subject_Keyword_Identified  \
# 0                                    NaN
# 1                                    ANC
# 2    Cape Town|Johannesburg|South Africa
# 3                                    NaN
# 4                           South Africa
# ..                                   ...
# 195                                   DA
# 196                         South Africa
# 197                               ANC|DA
# 198                         South Africa
# 199                    EFF|Julius Malema
#
#                       Article_Topic_Keyword_Identified  \
# 0      Armed Conflict|Crime & Terrorism|State Security
# 1                                                  NaN
# 2    Armed Conflict|Civil Unrest & Protest|Crime & ...
# 3                                       State Security
# 4                     Crime & Terrorism|State Security
# ..                                                 ...
# 195                                     State Security
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                Leadership delivery
#
#                                         Combined_Names  \
# 0    Benny Gantz|Benjamin Netanyahu|Yoav Gallant|Ga...
# 1    Mathabatha|Stan Mathabatha|Reuben Madadzhe|Reg...
# 2    Axed MK|Jabulani Khumalo|Ajay Gupta|Lethabo Le...
# 3    Saulos Chilima|Saulos Klaus|Saulos Klaus|Valen...
# 4    Axing|Nigel Sibanda/|Grandi Theunissen|Jaco Ba...
# ..                                                 ...
# 195  Saulos Chilima|Saulos Chilima|Lazarus Chakwera...
# 196  Lindela Mashigo|eNCA|Lehakwe Tlali Soweto Gosp...
# 197  Raymond Zondo|Zondo the National Assembly|the ...
# 198  Gemalto Altron Fintech Southern Africa The Dep...
# 199  Julius Malema|Twerka|Julius Malema|Julius Male...
#
#                                        Processed_Names
# 0    benny gantz benjamin netanyahu yoav gallant ga...
# 1    mathabatha stan mathabatha reuben madadzhe reg...
# 2    axed mk jabulani khumalo ajay gupta lethabo le...
# 3    saulos chilima saulos klaus saulos klaus valen...
# 4    axing nigel sibanda grandi theunissen jaco bar...
# ..                                                 ...
# 195  saulos chilima saulos chilima lazarus chakwera...
# 196  lindela mashigo enca lehakwe tlali soweto gosp...
# 197  raymond zondo zondo national assembly national...
# 198  gemalto altron fintech southern africa departm...
# 199  julius malema twerka julius malema julius male...
#
# [200 rows x 11 columns]
