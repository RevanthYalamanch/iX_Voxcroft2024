# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# Load the dataset
data = pd.read_csv('cleandata_processed.csv', nrows=6258)



# Define a simple stopwords list
simple_stopwords = set([
    'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
    'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself',
    'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which',
    'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be',
    'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an',
    'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by',
    'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before',
    'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over',
    'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why',
    'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no',
    'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will',
    'just', 'don', 'should', 'now'
])

# Preprocessing function without NLTK
def preprocess_text_simple(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()  # Lowercase
    text = re.sub(r'\d+', '', text)  # Remove digits
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    words = text.split()
    words = [word for word in words if word not in simple_stopwords]  # Remove stopwords
    return ' '.join(words)

# Apply preprocessing to the Article_Body column
data['Processed_Article_Body'] = data['Article_Body'].apply(preprocess_text_simple)

# Initialize the TF-IDF vectorizer with a maximum number of features
vectorizer = TfidfVectorizer(max_features=1000)

# Fit and transform the processed article body text
tfidf_matrix = vectorizer.fit_transform(data['Processed_Article_Body'])

# Convert the TF-IDF matrix to a DataFrame for better readability
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

# Save the TF-IDF DataFrame to a CSV file
tfidf_df.to_csv('tfidf_analysis_results.csv', index=False)

# Function to get the top N terms with the highest TF-IDF scores
def get_top_n_terms(tfidf_matrix, feature_names, top_n=10):
    summed_tfidf = tfidf_matrix.sum(axis=0)
    sorted_indices = np.argsort(summed_tfidf)[::-1][:top_n]
    top_terms = [(feature_names[i], summed_tfidf[0, i]) for i in sorted_indices]
    return top_terms

# Get the feature names
feature_names = vectorizer.get_feature_names_out()

# Get the top 20 terms across all documents
top_terms = get_top_n_terms(tfidf_matrix, feature_names, top_n=20)

# Print the top terms
for term, score in top_terms:
     print(f"Term: {term}, Score: {score[0,0]:.4f}")
# Out:
# Term: [['facd' 'ca' 'rec' 'ee' 'fe' 'caa' 'fff' 'nogap' 'eab' 'fcb' 'inset'
#   'bbfa' 'tdi_' 'ea' 'webkit' 'rgba' 'koo' 'flipboard' 'viber' 'tumblr'
#   'tabs' 'notext' 'kakao' 'naver' 'gettr' 'cf' 'pinterest' 'cde' 'vk'
#   'digg' 'stumbleupon' 'handler' 'reddit' 'telegram' 'copy_url' 'font'
#   'ec' 'arrow' 'linkedin' 'width' 'radius' 'padding' 'colored'
#   'transparent' 'bar' 'transform' 'opacity' 'align' 'margin' 'shadow'
#   'relative' 'bg' 'solid' 'box' 'absolute' 'background' 'height' 'none'
#   'index' 'expand' 'whatsapp' 'block' 'medicine' 'transition' 'display'
#   'print' 'style' 'uct' 'bottom' 'max' 'px' 'sharing' 'middle' 'hiv'
#   'text' 'color' 'check' 'either' 'debuts' 'raid' 'size' 'mngomezulu'
#   'canon' 'stand' 'leicester' 'schools' 'camps' 'dm' 'tigers' 'built'
#   'target' 'word' 'ministry' 'eagles' 'closely' 'featuring' 'backs'
#   'wing' 'main' 'fouche' 'ons' 'foreign' 'groups' 'twickenham' 'southern'
#   'vodacom' 'jasper' 'forwards' 'exactly' 'uk' 'matters' 'heart' 'border'
#   'dixon' 'phepsi' 'gantz' 'society' 'kolbe' 'palestinians' 'plans'
#   'nuseirat' 'berg' 'den' 'quan' 'buthelezi' 'whose' 'nie' 'takes'
#   'assault' 'jason' 'neethling' 'ethan' 'russian' 'grant' 'electoral'
#   'building' 'pressure' 'om' 'opposition' 'living' 'mamelodi' 'doubt'
#   'wiese' 'masuku' 'difficult' 'conference' 'rassie' 'double' 'edwill'
#   'feinberg' 'join' 'umkhonto' 'sacha' 'commitment' 'care' 'everything'
#   'growing' 'la' 'icon' 'brought' 'special' 'green' 'leadership' 'via'
#   'east' 'alignment' 'politics' 'region' 'release' 'force' 'venter' 'ps'
#   'cabinet' 'anti' 'eskom' 'individuals' 'fighting' 'released' 'nation'
#   'although' 'soon' 'response' 'gave' 'mail' 'dance' 'biden' 'regional'
#   'weeks' 'expressed' 'billion' 'means' 'elected' 'tuesday' 'votes'
#   'emirates' 'lives' 'network' 'respectively' 'concerns' 'heavy' 'fight'
#   'horn' 'wesizwe' 'ceasefire' 'central' 'australia' 'infrastructure'
#   'zondo' 'biggest' 'selection' 'education' 'trade' 'director' 'chance'
#   'provide' 'fact' 'congress' 'risk' 'agreement' 'defence' 'pollard'
#   'hugo' 'space' 'artist' 'career' 'te' 'voters' 'meeting' 'smith'
#   'capital' 'du' 'investment' 'authorities' 'route' 'image' 'everyone'
#   'included' 'intelligence' 'focus' 'programme' 'various' 'photo' 'sea'
#   'turn' 'families' 'almost' 'meanwhile' 'try' 'official' 'date' 'rights'
#   'needed' 'conflict' 'injury' 'bank' 'evening' 'followed' 'eight' 'ago'
#   'environment' 'maverick' 'poor' 'blue' 'whether' 'speaking' 'goal'
#   'metro' 'williams' 'along' 'theatre' 'prime' 'communities' 'london'
#   'build' 'feel' 'siya' 'course' 'remains' 'story' 'project' 'french'
#   'appeared' 'cannot' 'weather' 'supply' 'close' 'march' 'remain'
#   'reportedly' 'andre' 'single' 'believe' 'paris' 'works' 'father'
#   'opportunity' 'foundation' 'ukraine' 'result' 'damage' 'list' 'fair'
#   'includes' 'section' 'content' 'province' 'eastern' 'value' 'injured'
#   'thought' 'previously' 'august' 'though' 'personal' 'give' 'plan'
#   'demand' 'period' 'something' 'secretary' 'games' 'weekend' 'england'
#   'enough' 'met' 'rise' 'constitutional' 'jordan' 'ceo' 'considered'
#   'house' 'using' 'died' 'ground' 'less' 'position' 'live' 'commission'
#   'non' 'ben' 'key' 'step' 'name' 'currently' 'serious' 'contract'
#   'opening' 'coming' 'short' 'states' 'electricity' 'playing' 'teams'
#   'done' 'west' 'jacob' 'ever' 'towards' 'operations' 'current'
#   'november' 'campaign' 'alcaraz' 'air' 'human' 'september' 'mother'
#   'yakhe' 'wrote' 'uncapped' 'impact' 'data' 'football' 'especially'
#   'price' 'terms' 'hope' 'field' 'deputy' 'het' 'palestinian' 'visit'
#   'km' 'potential' 'interest' 'missing' 'order' 'george' 'championship'
#   'leading' 'likely' 'stage' 'vs' 'often' 'north' 'possible' 'published'
#   'emsebenzini' 'front' 'moment' 'technology' 'hooker' 'title'
#   'democracy' 'issues' 'forces' 'press' 'points' 'member' 'better'
#   'talks' 'reuters' 'hendrikse' 'dead' 'malema' 'leaders' 'job' 'little'
#   'cut' 'youth' 'december' 'champions' 'let' 'increase' 'needs' 'urc'
#   'efforts' 'merwe' 'october' 'finished' 'university' 'minutes' 'deal'
#   'mkp' 'comes' 'application' 'given' 'search' 'ntusi' 'child' 'played'
#   'getting' 'great' 'cyril' 'contact' 'happy' 'able' 'nelson'
#   'conditions' 'countries' 'york' 'private' 'include' 'uzulu' 'point'
#   'son' 'hard' 'pm' 'really' 'night' 'orlando' 'named' 'complaint' 'keep'
#   'claims' 'role' 'research' 'failed' 'workers' 'mps' 'france' 'injuries'
#   'al' 'safety' 'ages' 'earlier' 'freedom' 'saying' 'netherlands'
#   'macron' 'morning' 'kaizer' 'strong' 'saw' 'rescue' 'online' 'seats'
#   'daily' 'act' 'golf' 'administration' 'global' 'total' 'hours' 'april'
#   'areas' 'victim' 'return' 'major' 'festival' 'revealed' 'ireland'
#   'cost' 'available' 'municipality' 'winner' 'videos' 'der' 'side'
#   'knysna' 'europe' 'received' 'showed' 'economy' 'didn' 'become' 'load'
#   'dhl' 'term' 'hit' 'announced' 'challenges' 'democratic' 'open' 'stop'
#   'asked' 'reports' 'scene' 'access' 'food' 'seven' 'bring' 'general'
#   'popular' 'lot' 'land' 'late' 'attack' 'eu' 'process' 'za' 'images'
#   'climate' 'running' 'system' 'significant' 'mandela' 'alleged'
#   'started' 'outside' 'shows' 'move' 'russia' 'area' 'finish' 'ngenxa'
#   'platform' 'per' 'park' 'series' 'red' 'full' 'forward' 'things' 'lost'
#   'decision' 'latest' 'challenge' 'constitution' 'sector' 'person'
#   'sport' 'history' 'different' 'used' 'johannesburg' 'least' 'previous'
#   'action' 'find' 'might' 'play' 'half' 'abantu' 'profile' 'companies'
#   'wife' 'ethekwini' 'award' 'operation' 'matter' 'energy' 'form' 'love'
#   'allegedly' 've' 'change' 'rapper' 'working' 'ai' 'pretoria' 'medical'
#   'white' 'important' 'njengoba' 'confirmed' 'ensure' 'proteas' 'level'
#   'already' 'today' 'taken' 'put' 'despite' 'others' 'tiktok' 'watch'
#   'black' 'look' 'recently' 'pirates' 'meet' 'say' 'report' 'tournament'
#   'recent' 'held' 'africans' 'league' 'accused' 'service' 'thursday'
#   'fire' 'always' 'near' 'affected' 'future' 'across' 'relationship'
#   'officials' 'growth' 'several' 'india' 'months' 'camp' 'dr' 'attention'
#   'january' 'victory' 'think' 'alliance' 'yet' 'legal' 'game' 'kakhulu'
#   'hospital' 'early' 'ukuba' 'centre' 'performance' 'start' 'big'
#   'expected' 'player' 'called' 'management' 'runs' 'taking' 'limpopo'
#   'military' 'office' 'ahead' 'cookies' 'personalise' 'com' 'industry'
#   'cookie' 'hostages' 'led' 'behind' 'majority' 'shot' 'five' 'face'
#   'known' 'music' 'six' 'privacy' 'fashion' 'council' 'call' 'en' 'line'
#   'number' 'winning' 'view' 're' 'without' 'results' 'provincial'
#   'security' 'small' 'away' 'manage' 'bay' 'residents' 'leader'
#   'springbok' 'western' 'within' 'statement' 'stadium' 'use' 'head'
#   'development' 'much' 'uses' 'women' 'company' 'independent' 'lions'
#   'tv' 'letoya' 'seen' 'event' 'never' 'commenting' 'came' 'past' 'lead'
#   'times' 'sundowns' 'unity' 'corruption' 'together' 'help' 'show'
#   'crime' 'vote' 'united' 'best' 'record' 'looking' 'hollywoodbets'
#   'continue' 'involved' 'lo' 'want' 'financial' 'erasmus' 'fans' 'got'
#   'days' 'coach' 'real' 'far' 'bulls' 'july' 'every' 'local' 'ncwadi'
#   'picture' 'death' 'instagram' 'european' 'chief' 'improve' 'due'
#   'later' 'essential' 'quick' 'third' 'among' 'steyn' 'body' 'icomrades'
#   'long' 'school' 'case' 'website' 'pay' 'training' 'kodwa' 'facebook'
#   'sitting' 'know' 'law' 'part' 'following' 'wiersma' 'incident' 'market'
#   'murder' 'making' 'young' 'come' 'justice' 'elections' 'tweet' 'final'
#   'post' 'th' 'family' 'isithombe' 'uma' 'policies' 'added' 'need'
#   'kwazulu' 'end' 'hamas' 'iec' 'reported' 'health' 'daughter' 'le'
#   'woman' 'spokesperson' 'power' 'based' 'public' 'economic' 'around'
#   'business' 'springboks' 'friday' 'see' 'went' 'club' 'top' 'ngoba'
#   'shared' 'going' 'reading' 'star' 'go' 'water' 'wales' 'match' 'men'
#   'money' 'please' 'international' 'rugby' 'even' 'must' 'bafana' 'win'
#   'email' 'source' 'briefly' 'told' 'children' 'place' 'another'
#   'community' 'department' 'ngo' 'durban' 'policy' 'monday' 'good'
#   'natal' 'gnu' 'including' 'assembly' 'support' 'eff' 'month' 'war'
#   'gaza' 'took' 'information' 'minister' 'emva' 'still' 'fjs' 'way'
#   'however' 'found' 'get' 'high' 'de' 'town' 'won' 'set' 'chiefs' 'man'
#   'killed' 'day' 'take' 'right' 'ramaphosa' 'services' 'well' 'israel'
#   'zuma' 'td' 'clear' 'work' 'members' 'million' 'state' 'die' 'home'
#   'make' 'life' 'coalition' 'accident' 'israeli' 'second' 'cup' 'many'
#   'experience' 'free' 'week' 'since' 'former' 'season' 'made' 'saturday'
#   'country' 'car' 'video' 'test' 'according' 'could' 'four' 'comrades'
#   'sunday' 'race' 'van' 'stormers' 'election' 'sharks' 'back' 'road' 'id'
#   'group' 'city' 'left' 'mk' 'article' 'squad' 'may' 'run' 'media' 'next'
#   'sa' 'parties' 'team' 'sign' 'twitter' 'political' 'says' 'social'
#   'comment' 'old' 'parliament' 'years' 'drive' 'three' 'president' 'co'
#   'last' 'marathon' 'court' 'june' 'cape' 'uthe' 'da' 'african'
#   'shebeshxt' 'us' 'news' 'vehicle' 'like' 'world' 'js' 'time' 'would'
#   'government' 'police' 'two' 'read' 'new' 'one' 'players' 'first'
#   'people' 'national' 'party' 'ukuthi' 'year' 'also' 'africa' 'share'
#   'anc' 'south' 'said']], Score: 0.4202

# %%
line_number = 6260

with open('cleandata_processed.csv', 'r') as file:
    for current_line_number, line in enumerate(file, start=1):
        if current_line_number == line_number:
            print(line)
            break
# Out:
# The devices fitted to Hera and Royal Wasi weigh just 3.2 grams each and are powered by tiny solar panels roughly the size of the nail on a human pinkie finger.

# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
import spacy
import numpy as np

# Load the pre-trained spaCy model
nlp = spacy.load("en_core_web_sm")

# Load your dataset
new_data = pd.read_csv('cleandata_processed.csv', nrows=6258)  # Ensure 'data_processed.csv' is in the same directory

# Combine relevant columns
new_data['Combined_Names'] = new_data['Name'].fillna('') + ' ' + new_data['Article_Themes_AI_Model'].fillna('')

# Define a simple stopwords list
simple_stopwords = set([
    'a', 'an', 'the', 'and', 'or', 'but', 'if', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with',
    'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from',
    'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there',
    'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such',
    'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don',
    'should', 'now'
])

# Preprocess text
def preprocess_text_simple(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()  # Lowercase
    text = re.sub(r'\d+', '', text)  # Remove digits
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    words = text.split()
    words = [word for word in words if word not in simple_stopwords]  # Remove stopwords
    return ' '.join(words)

new_data['Processed_Names'] = new_data['Combined_Names'].apply(preprocess_text_simple)

# Initialize TF-IDF Vectorizer
vectorizer = TfidfVectorizer(max_features=1000)
tfidf_matrix = vectorizer.fit_transform(new_data['Processed_Names'])
feature_names = vectorizer.get_feature_names_out()

# Get top N terms
def get_top_n_terms(tfidf_matrix, feature_names, top_n=10):
    summed_tfidf = tfidf_matrix.sum(axis=0)
    sorted_indices = np.argsort(summed_tfidf.A1)[::-1][:top_n]

    top_terms = [(feature_names[i], summed_tfidf[0, i]) for i in sorted_indices]
    return top_terms

top_terms = get_top_n_terms(tfidf_matrix, feature_names, top_n=20)

# Print top terms in "term-value, term-value, etc." format
top_terms_str = ', '.join([f"{term}-{float(value):.4f}" for term, value in top_terms])
print("Top TF-IDF Terms:", top_terms_str)
# Out:
# Top TF-IDF Terms: secondary-1083.2037, primary-1083.2037, politics-501.8300, uncategorized-482.0231, sport-479.3240, entertainment-337.1080, arts-337.1080, human-336.4550, interest-307.4623, culture-298.7359, law-288.7092, crime-278.2821, economy-264.1351, emergency-252.2693, political-251.1274, media-248.6320, justice-245.7942, business-238.0946, incident-235.2170, government-201.6397

# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
import spacy
import numpy as np

# Load the pre-trained spaCy model
nlp = spacy.load("en_core_web_sm")

# Load your dataset
new_data = pd.read_csv('cleandata_processed.csv', nrows=6258)  # Ensure 'data_processed.csv' is in the same directory

# Combine relevant columns
new_data['Combined_Names'] = new_data['Name'].fillna('') + ' ' + new_data['Article_Themes_AI_Model'].fillna('')

# Define a simple stopwords list
simple_stopwords = set([
    'a', 'an', 'the', 'and', 'or', 'but', 'if', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with',
    'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from',
    'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there',
    'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such',
    'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don',
    'should', 'now'
])

# Preprocess text
def preprocess_text_simple(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()  # Lowercase
    text = re.sub(r'\d+', '', text)  # Remove digits
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    words = text.split()
    words = [word for word in words if word not in simple_stopwords]  # Remove stopwords
    return ' '.join(words)

new_data['Processed_Names'] = new_data['Combined_Names'].apply(preprocess_text_simple)

# Initialize TF-IDF Vectorizer
vectorizer = TfidfVectorizer(max_features=1000)
tfidf_matrix = vectorizer.fit_transform(new_data['Processed_Names'])
feature_names = vectorizer.get_feature_names_out()

# Preprocess names similarly
new_data['Processed_Individual_Names'] = new_data['Name'].apply(preprocess_text_simple)
processed_names = new_data['Processed_Individual_Names'].unique()

# Assign TF-IDF scores to names
tfidf_scores = {}

for name in processed_names:
    if name in feature_names:
        name_index = np.where(feature_names == name)[0][0]
        tfidf_scores[name] = tfidf_matrix[:, name_index].sum()

# Print TF-IDF scores for names
for name, score in tfidf_scores.items():
    print(f"{name}: {score:.4f}")
# Out:
# theunissen: 2.7976
# eskom: 2.9184
# ramaphosa: 61.0263
# ramp: 45.9069
# steyn: 24.2435
# chakwera: 5.0601
# amakhosi: 2.7085
# mpho: 4.8082
# magashule: 4.7242
# aslan: 1.9962
# alcaraz: 6.3239
# biden: 12.0605
# bill: 2.3538
# bush: 3.7468
# macron: 17.5503
# kolbe: 17.2976
# leinster: 7.7263
# gumede: 8.9691
# vinicius: 7.0372
# ajay: 3.1580
# anil: 2.1573
# gupta: 7.0514
# zuma: 48.9237
# simola: 3.1161
# peter: 14.0139
# toby: 4.4154
# malinga: 1.5928
# mabaso: 2.2692
# mukaddam: 2.4409
# john: 16.1690
# leli: 2.9277
# libbok: 2.7499
# kabo: 2.8157
# billiat: 2.8271
# njengoba: 10.0604
# kim: 5.4845
# gabriel: 1.4461
# elton: 2.7940
# wilders: 2.8691
# maria: 1.4355
# ann: 1.9474

# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# Load your dataset
new_data = pd.read_csv('cleandata_processed.csv', nrows=6259)  # Ensure 'cleandata_processed.csv' is in the same directory

# Combine relevant columns
new_data['Combined_Names'] = new_data['Name'].fillna('') + ' ' + new_data['Article_Themes_AI_Model'].fillna('')

# Define a simple stopwords list
simple_stopwords = set([
    'a', 'an', 'the', 'and', 'or', 'but', 'if', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with',
    'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from',
    'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there',
    'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such',
    'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don',
    'should', 'now'
])

# Preprocess text
def preprocess_text_simple(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()  # Lowercase
    text = re.sub(r'\d+', '', text)  # Remove digits
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    words = text.split()
    words = [word for word in words if word not in simple_stopwords]  # Remove stopwords
    return ' '.join(words)

new_data['Processed_Names'] = new_data['Combined_Names'].apply(preprocess_text_simple)

# Initialize TF-IDF Vectorizer
vectorizer = TfidfVectorizer(max_features=1000)
tfidf_matrix = vectorizer.fit_transform(new_data['Processed_Names'])
feature_names = vectorizer.get_feature_names_out()

# Preprocess names similarly and include only those with more than two words but fewer than four words
def preprocess_name(name):
    processed_name = preprocess_text_simple(name)
    word_count = len(processed_name.split())
    if 2 < word_count:  # Include only names with more than two words but fewer than four words
        return processed_name
    return ""

new_data['Processed_Individual_Names'] = new_data['Name'].apply(preprocess_name)
processed_names = new_data['Processed_Individual_Names'].unique()
processed_names = [name for name in processed_names if name]  # Remove empty strings

# Debug: Print processed names to verify
print("Processed Names:", processed_names)

# Assign TF-IDF scores to names
tfidf_scores = {}

for name in processed_names:
    name_terms = name.split()
    for term in name_terms:
        if term in feature_names:
            term_index = np.where(feature_names == term)[0][0]
            score = tfidf_matrix[:, term_index].sum()
            if name in tfidf_scores:
                tfidf_scores[name] += score
            else:
                tfidf_scores[name] = score

# Debug: Print tfidf_scores to verify
print("TF-IDF Scores:", tfidf_scores)

# Print TF-IDF scores for names
for name, score in tfidf_scores.items():
    print(f"{name}: {score:.4f}")
# Out:
# Processed Names: ['gerda gerda steyn', 'darren stewart gallo images', 'al jama ah', 'gemalto altron fintech southern africa', 'lood de jager jean kleyn', 'kurt lee arendse', 'nomusa dube ncube', 'saulos klaus chilima', 'lazarus chakwera search', 'marikana https co eipgdydxtr ramaphosa', 'marikana https co eipgdydxtr', 'linda thomas greenfield', 'omar al bashir', 'paul kruger gate', 'ursula von der leyen', 'frennie shivambu gallo images', 'renowned poet mzwakhe mbuli', 'satyendra singh sahni', 'geordin hill lewis', 'john maynard keynes', 'gossipmonger musa khawula', 'dawie de villiers', 'richard huggard gallo images', 'pixley ka isaka', 'adv zuraya adhikarie', 'lethabo lejoy mathato', 'md grant orsmond', 'jose jordan afp file vinicius junior', 'lungi de ville', 'captian fc van wyk', 'lethabo lejoy mathatho', 'maegan leigh jacobs', 'skhothane sa pitori', 'kabza de small', 'fw de klerk', 'majlis e ittehadul muslimeen', 'n biren singh', 'rex van schalkwyk', 'des van rooyen', 'von der leyen', 'al shabaab years ago', 'hassan ya u', 'abdullahi yunusa kankara', 'ch