# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# Load the dataset
data = pd.read_csv('cleandata_processed.csv', nrows=500)

# Define a simple stopwords list
simple_stopwords = set([
    'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
    'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself',
    'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which',
    'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be',
    'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an',
    'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by',
    'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before',
    'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over',
    'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why',
    'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no',
    'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will',
    'just', 'don', 'should', 'now'
])

# Preprocessing function without NLTK
def preprocess_text_simple(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()  # Lowercase
    text = re.sub(r'\d+', '', text)  # Remove digits
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    words = text.split()
    words = [word for word in words if word not in simple_stopwords]  # Remove stopwords
    return ' '.join(words)

# Apply preprocessing to the Article_Body column
data['Processed_Article_Body'] = data['Article_Body'].apply(preprocess_text_simple)

# Initialize the TF-IDF vectorizer with a maximum number of features
vectorizer = TfidfVectorizer(max_features=1000)

# Fit and transform the processed article body text
tfidf_matrix = vectorizer.fit_transform(data['Processed_Article_Body'])

# Convert the TF-IDF matrix to a DataFrame for better readability
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

# Save the TF-IDF DataFrame to a CSV file
tfidf_df.to_csv('tfidf_analysis_results.csv', index=False)

# Function to get the top N terms with the highest TF-IDF scores
def get_top_n_terms(tfidf_matrix, feature_names, top_n=10):
    summed_tfidf = tfidf_matrix.sum(axis=0)
    sorted_indices = np.argsort(summed_tfidf)[::-1][:top_n]
    top_terms = [(feature_names[i], summed_tfidf[0, i]) for i in sorted_indices]
    return top_terms

# Get the feature names
feature_names = vectorizer.get_feature_names_out()

# Get the top 20 terms across all documents
top_terms = get_top_n_terms(tfidf_matrix, feature_names, top_n=20)

# Print the top terms
for term, score in top_terms:
     print(f"Term: {term}, Score: {score[0,0]:.4f}")
# Out:
# Term: [['moment' 'unlikely' 'blinken' 'allies' 'matters' 'movement' 'half'
#   'otherwise' 'ukrainian' 'speaking' 'reach' 'switzerland' 'else' 'seems'
#   'conflict' 'concerns' 'governance' 'simply' 'territory' 'wing' 'drop'
#   'claim' 'courts' 'union' 'attacks' 'happened' 'france' 'destruction'
#   'likely' 'aimed' 'trip' 'towards' 'subkh' 'patriotic' 'special'
#   'candidates' 'phase' 'knee' 'hands' 'avoid' 'opposition' 'best' 'felt'
#   'communist' 'noted' 'title' 'job' 'formed' 'evening' 'early'
#   'totalenergies' 'calling' 'forwards' 'versfeld' 'partner'
#   'consequences' 'mayor' 'anti' 'russian' 'means' 'furthermore' 'keep'
#   'double' 'der' 'goes' 'door' 'zelensky' 'sidelined' 'option' 'share'
#   'research' 'mean' 'ready' 'rights' 'served' 'looking' 'required' 'meet'
#   'everyone' 'chance' 'hold' 'macron' 'kzn' 'fighters' 'name' 'approach'
#   'nadal' 'represent' 'true' 'electricity' 'zealand' 'leadership' 'feel'
#   'leinster' 'spot' 'sentences' 'repeatedly' 'great' 'ambassador'
#   'particularly' 'eagles' 'post' 'ways' 'leave' 'prison' 'interest'
#   'investment' 'company' 'non' 'documents' 'weekend' 'succeed'
#   'celimpilo' 'offence' 'described' 'alleged' 'foreign' 'swearing'
#   'experienced' 'gain' 'climate' 'gallo' 'extend' 'main' 'comes'
#   'infrastructure' 'photo' 'immediately' 'serve' 'administration' 'stop'
#   'electoral' 'racially' 'criminals' 'highest' 'single' 'couple'
#   'massive' 'idea' 'environmental' 'ever' 'fall' 'order' 'tuesday'
#   'similar' 'available' 'kept' 'lack' 'started' 'progress' 'relationship'
#   'almost' 'mountain' 'done' 'lot' 'durban' 'soldiers' 'tigers' 'brazil'
#   'sacp' 'billion' 'partners' 'follow' 'andre' 'behind' 'efforts' 'look'
#   'french' 'trade' 'crisis' 'delivery' 'batters' 'posted' 'difficult'
#   'anyone' 'different' 'individuals' 'term' 'apartheid' 'raymond'
#   'visitors' 'morning' 'accommodation' 'grand' 'lose' 'hope' 'starting'
#   'sentence' 'rassie' 'ad' 'car' 'jacob' 'prime' 'protection'
#   'palestinian' 'india' 'outside' 'democrats' 'sparked' 'loftus'
#   'germany' 'joint' 'dropped' 'official' 'environment' 'biden' 'really'
#   'includes' 'names' 'cheslin' 'released' 'groups' 'continues' 'show'
#   'kaizer' 'allow' 'campaign' 'legislation' 'shot' 'votes' 'bloemfontein'
#   'whether' 'conduct' 'marxist' 'might' 'operation' 'removed' 'un'
#   'session' 'cancer' 'twickenham' 'causing' 'mccarthy' 'low' 'netanyahu'
#   'winning' 'change' 'explore' 'black' 'plus' 'update' 'nature' 'believe'
#   'challenge' 'event' 'selection' 'thus' 'often' 'alongside' 'lead'
#   'contempt' 'rising' 'leading' 'august' 'filed' 'democracy' 'present'
#   'domestic' 'line' 'greenwashing' 'independent' 'johannesburg' 'quarter'
#   'fight' 'image' 'put' 'revealed' 'addressed' 'economy' 'forces'
#   'matches' 'commission' 'denied' 'scheduled' 'human' 'rest' 'player'
#   'hard' 'issues' 'demanded' 'province' 'weeks' 'trying' 'saw' 'capital'
#   'complaint' 'brothers' 'size' 'boys' 'possible' 'sent' 'reportedly'
#   'cut' 'watch' 'seat' 'industry' 'decades' 'picked' 'committed' 'field'
#   'uk' 'board' 'offer' 'front' 'series' 'range' 'impressive' 'kock'
#   'therefore' 'conference' 'pga' 'little' 'table' 'ensuring' 'pro'
#   'period' 'began' 'night' 'release' 'bring' 'shared' 'leaders' 'threat'
#   'taken' 'publication' 'costs' 'fast' 'positive' 'nassau' 'nortje'
#   'county' 'result' 'fifth' 'worldwide' 'supported' 'politics' 'position'
#   'talks' 'quality' 'freedom' 'wesizwe' 'gunmen' 'opposed' 'scene'
#   'recently' 'maverick' 'stated' 'politicians' 'dm' 'known' 'ban'
#   'defence' 'experts' 'centre' 'fighting' 'video' 'fixtures'
#   'opportunity' 'prevent' 'secretary' 'yet' 'access' 'toss' 'behaviour'
#   'later' 'meeting' 'today' 'strong' 'remain' 'kilometre' 'hikes'
#   'charged' 'thought' 'contact' 'earlier' 'suicide' 'april' 'opened'
#   'hridoy' 'umkhonto' 'agreement' 'pm' 'didn' 'plan' 'total' 'join'
#   'cyril' 'though' 'makhene' 'short' 'jail' 'give' 'showed' 'zimbabwe'
#   'shivambu' 'think' 'section' 'march' 'turn' 'mahmudullah' 'smotrich'
#   'orthodox' 'accused' 'urc' 'delivered' 'past' 'birds' 'rules'
#   'established' 'impact' 'handed' 'denny' 'least' 'message' 'gestures'
#   'meanwhile' 'come' 'better' 'facing' 'situation' 'point' 'stage'
#   'force' 'eu' 'needed' 'global' 'km' 'cricket' 'previous' 'move'
#   'saying' 'say' 'whose' 'september' 'ifp' 'alliance' 'legislature'
#   'playing' 'injury' 'zverev' 'although' 'executive' 'especially' 'held'
#   'land' 'premier' 'wales' 'happy' 'advantage' 'junior' 'key' 'played'
#   'potential' 'eight' 'family' 'interdict' 'julius' 'across'
#   'negotiations' 'call' 'death' 'middendorp' 'legal' 'want' 'latest'
#   'popular' 'project' 'despite' 'air' 'kolbe' 'pretoria' 'gosiame'
#   'shooting' 'hendricks' 'lebohang' 'fire' 'health' 'know' 'published'
#   'away' 'less' 'mdf' 'october' 'ensure' 'gave' 'safety' 'voters' 'aid'
#   'camp' 'july' 'arrested' 'working' 'use' 'able' 'level' 'nec' 'lazarus'
#   'body' 'nothing' 'terms' 'nation' 'demand' 'women' 'deputy' 'trust'
#   'points' 'late' 'spain' 'spanish' 'al' 'named' 'wife' 'november' 'died'
#   'hasan' 'sakib' 'daily' 'help' 'missing' 'proposal' 'market' 'claims'
#   'address' 'men' 'win' 'attack' 'history' 'price' 'except' 'gumede'
#   'keswa' 'letoya' 'divorce' 'third' 'tourism' 'springbok' 'expert'
#   'images' 'khumalo' 'vodacom' 'seen' 'management' 'cannot' 'followed'
#   'posts' 'reduction' 'play' 'member' 'report' 'beyond' 'lilongwe'
#   'energy' 'forward' 'together' 'december' 'advertising' 'step'
#   'performance' 'opening' 'bowled' 'victory' 'allegations' 'balls'
#   'london' 'lions' 'due' 'always' 'gantz' 'house' 'big' 'children'
#   'taking' 'championship' 'needs' 'systems' 'evidence' 'injuries'
#   'saulos' 'seven' 'ago' 'near' 'reports' 'condolences' 'bill' 'failed'
#   'let' 'ruling' 'lebo' 'injured' 'authorities' 'actress' 'came' 'game'
#   'become' 'decision' 'deal' 've' 'rugby' 'hike' 'loss' 'confirmed'
#   'spokesperson' 'letter' 'wants' 'ireland' 'bester' 'need' 'families'
#   'finance' 'summit' 'ball' 'problem' 'wrote' 'led' 'chiefs' 'emirates'
#   'process' 'based' 'abuse' 'test' 'sithole' 'democratic' 'iec' 'overs'
#   'committee' 'speaker' 'things' 'system' 'fraud' 'affected' 'mzuzu'
#   'date' 'race' 'mass' 'dismissed' 'ultra' 'wicket' 'rule' 'states'
#   'number' 'general' 'thursday' 'tournament' 'israeli' 'looked'
#   'parliamentary' 'africans' 'birth' 'nine' 'criminal' 'sector' 'never'
#   'racism' 'officers' 'cup' 'even' 'following' 'peace' 'vice' 'important'
#   'nigeria' 'making' 'spurs' 'judge' 'record' 'months' 'ap' 'majority'
#   'per' 'include' 'six' 'results' 'shows' 'broos' 'operations' 'enough'
#   'insults' 'matter' 'pec' 'miller' 'money' 'financial' 'others' 'action'
#   'resolution' 'received' 'ground' 'medical' 'role' 'make' 'gupta' 'days'
#   'long' 'cabinet' 'mkp' 'going' 'growth' 'full' 'klaasen' 'many'
#   'passing' 'find' 'lost' 'good' 'season' 'among' 'extortion' 'school'
#   'instagram' 'airport' 'given' 'allegedly' 'winner' 'leader' 'several'
#   'club' 'office' 'face' 'open' 'development' 'announced' 'asked'
#   'called' 'already' 'work' 'zondo' 'within' 'start' 'uses' 'cookies'
#   'personalise' 'cookie' 'privacy' 'progressive' 'elected' 'road' 'fuel'
#   'seats' 'return' 'squad' 'much' 'form' 'countries' 'carrying'
#   'expected' 'place' 'charges' 'list' 'hostages' 'man' 'essential'
#   'commenting' 'tshwane' 'please' 'top' 'picture' 'manage' 'steyn'
#   'attention' 're' 'get' 'trial' 'ahead' 'ministers' 'every' 'trail'
#   'economic' 'went' 'week' 'five' 'times' 'department' 'second' 'added'
#   'public' 'major' 'got' 'way' 'around' 'tv' 'another' 'western'
#   'council' 'high' 'manifesto' 'currently' 'improve' 'benni' 'attend'
#   'article' 'million' 'star' 'th' 'quick' 'la' 'final' 'end' 'bafana'
#   'group' 'sars' 'malema' 'alcaraz' 'security' 'liga' 'part' 'united'
#   'reported' 'york' 'european' 'january' 'including' 'wickets' 'go'
#   'killed' 'football' 'business' 'laconco' 'service' 'provincial'
#   'website' 'valencia' 'vinicius' 'officials' 'tmpd' 'vote' 'maharaj'
#   'proteas' 'de' 'coach' 'home' 'information' 'comrades' 'fossil'
#   'policy' 'took' 'russia' 'marathon' 'head' 'won' 'markram' 'unity'
#   'nonku' 'ceasefire' 'still' 'case' 'mdluli' 'load' 'search' 'crime'
#   'local' 'justice' 'companies' 'policies' 'found' 'take' 'month' 'law'
#   'old' 'ukraine' 'application' 'aircraft' 'chief' 'continue' 'life'
#   'vehicle' 'elections' 'training' 'see' 'war' 'pa' 'must'
#   'constitutional' 'influence' 'park' 'constitution' 'next' 'without'
#   'khayelitsha' 'source' 'sunday' 'told' 'day' 'clear' 'town' 'friday'
#   'dhl' 'team' 'power' 'experience' 'run' 'state' 'limpopo' 'corruption'
#   'however' 'pay' 'fans' 'stormers' 'well' 'according' 'zuma' 'military'
#   'set' 'may' 'gaza' 'chakwera' 'players' 'services' 'bulls' 'gnu'
#   'incident' 'vs' 'dr' 'statement' 'community' 'hospital' 'support'
#   'shebeshxt' 'since' 'far' 'mps' 'media' 'free' 'reading' 'years'
#   'world' 'minister' 'racist' 'briefly' 'social' 'bangladesh' 'coalition'
#   'hollywoodbets' 'african' 'back' 'malawi' 'right' 'left' 'madrid'
#   'made' 'match' 'june' 'real' 'city' 'hamas' 'chilima' 'sharks'
#   'country' 'international' 'last' 'israel' 'runs' 'like' 'comment'
#   'election' 'could' 'four' 'plane' 'monday' 'sign' 'stadium' 'former'
#   'springboks' 'cape' 'police' 'co' 'news' 'three' 'one' 'sa' 'people'
#   'assembly' 'saturday' 'new' 'says' 'us' 'time' 'ramaphosa' 'read'
#   'parties' 'political' 'members' 'year' 'sitting' 'two' 'also' 'court'
#   'parliament' 'would' 'eff' 'first' 'president' 'mk' 'government' 'da'
#   'national' 'africa' 'party' 'south' 'anc' 'said']], Score: 0.9982

# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
import spacy
import numpy as np

# Load the pre-trained spaCy model
nlp = spacy.load("en_core_web_sm")

# Load your dataset
new_data = pd.read_csv('cleandata_processed.csv', nrows = 500)  # Ensure 'data_processed.csv' is in the same directory

# Combine relevant columns
new_data['Combined_Names'] = new_data['Name'].fillna('') + ' ' + new_data['Article_Themes_AI_Model'].fillna('')

# Preprocess text
def preprocess_text_simple(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()  # Lowercase
    text = re.sub(r'\d+', '', text)  # Remove digits
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    words = text.split()
    words = [word for word in words if word not in simple_stopwords]  # Remove stopwords
    return ' '.join(words)

new_data['Processed_Names'] = new_data['Combined_Names'].apply(preprocess_text_simple)

# Initialize TF-IDF Vectorizer
vectorizer = TfidfVectorizer(max_features=1000)
tfidf_matrix = vectorizer.fit_transform(new_data['Processed_Names'])
feature_names = vectorizer.get_feature_names_out()

# Get top N terms
def get_top_n_terms(tfidf_matrix, feature_names, top_n=10):
    summed_tfidf = tfidf_matrix.sum(axis=0)
    sorted_indices = np.argsort(summed_tfidf)[::-1][:top_n]
    top_terms = [(feature_names[i], summed_tfidf[0, i]) for i in sorted_indices]
    return top_terms

top_terms = get_top_n_terms(tfidf_matrix, feature_names, top_n=20)
print("Top TF-IDF Terms:", top_terms)

# Analyze context for "Biden"
for text in new_data['Combined_Names']:
    doc = nlp(text)
    biden_contexts = [sent for sent in doc.sents if "Biden" in sent.text]
    for context in biden_contexts:
        if "Joe" in context.text or "President" in context.text:
            print(f"Text: {text}")
            print("Context:", context)
            print("Refers to Joe Biden")
# Out:
# Top TF-IDF Terms: [(array([['leader', 'nozikhungo', 'dialogue', 'ritual', 'interreligious',
#         'tshona', 'ceremony', 'seelan', 'gobalsamy', 'sibeko', 'siphiti',
#         'charco', 'cranes', 'donati', 'robert', 'masilela', 'makwe',
#         'towell', 'körner', 'graeme', 'nader', 'mass', 'dj', 'dineo',
#         'ranaka', 'mohammed', 'marina', 'hijab', 'medvin', 'satyendra',
#         'sahni', 'singh', 'southern', 'fintech', 'gemalto', 'africa',
#         'altron', 'zuraya', 'adhikarie', 'adv', 'barnard', 'heine',
#         'lynnette', 'solomon', 'anil', 'merten', 'ferial', 'marianne',
#         'moloto', 'haffajee', 'mothapo', 'hitler', 'adolf', 'lagardien',
#         'andile', 'pot', 'ismail', 'irwin', 'pol', 'mngxitama', 'jim',
#         'sarah', 'yenesel', 'bendjama', 'amar', 'ursula', 'leyen', 'von',
#         'der', 'khanyi', 'connie', 'karabo', 'ferguson', 'mbau',
#         'moroka', 'jessica', 'wilmot', 'white', 'jake', 'coombs',
#         'andrew', 'bill', 'poet', 'renowned', 'jose', 'file', 'afp',
#         'jordan', 'mkylparty', 'mgjigga', 'frennie', 'hera', 'shangaan',
#         'demographics', 'darren', 'stewart', 'nigel', 'faro', 'witness',
#         'sibanda', 'nasiphi', 'maluleke', 'yolanda', 'moya', 'spencer',
#         'adams', 'jaco', 'grandi', 'agnesia', 'giorgia', 'petrequin',
#         'meloni', 'samuel', 'bashir', 'omar', 'sundowns', 'mamelodi',
#         'mccarthy', 'bakili', 'shanil', 'dzimbiri', 'muluzi', 'natural',
#         'aluzinc', 'resources', 'levitt', 'rael', 'magakoe', 'phill',
#         'sipho', 'mkhize', 'inderjeet', 'colson', 'howard', 'bradley',
#         'caster', 'semenya', 'michel', 'lacharite', 'paton', 'carol',
#         'lindiwe', 'bukele', 'nayib', 'sisulu', 'axing', 'elizabeth',
#         'gayton', 'villiers', 'dawie', 'cheeseboy', 'hill', 'geordin',
#         'lewis', 'gcwabe', 'ali', 'ongama', 'jaker', 'mpeta', 'loyiso',
#         'inospace', 'orsmond', 'md', 'imagine', 'rk', 'ndlovu',
#         'madadzhe', 'frans', 'danny', 'machaka', 'rosemary', 'molepo',
#         'reuben', 'jeremiah', 'molokomme', 'ngobeni', 'jimmy', 'reggie',
#         'mokwele', 'shapira', 'assaf', 'gadi', 'gallant', 'tzach',
#         'yoav', 'eisenkot', 'tal', 'inbal', 'shoham', 'stan', 'abahambe',
#         'jacques', 'nel', 'scheffler', 'scottie', 'bezalel', 'search',
#         'mk', 'axed', 'airport', 'mireille', 'xander', 'matjila',
#         'mushi', 'ncube', 'nomusa', 'dube', 'kuala', 'lumpur',
#         'lawrence', 'ibrahim', 'nevondwe', 'lufuno', 'claasen', 'larry',
#         'lynette', 'viola', 'amherd', 'schneider', 'peter', 'cassis',
#         'ignazio', 'dirk', 'kasambara', 'ralph', 'reagen', 'andre',
#         'traut', 'allen', 'gunmen', 'dm', 'huggard', 'mvelase', 'dipuo',
#         'diane', 'silcock', 'sally', 'moleshe', 'ruse', 'mmower',
#         'eskom', 'henry', 'mamothame', 'dladu', 'sheila', 'fransina',
#         'ka', 'isaka', 'pixley', 'john', 'maynard', 'keynes', 'pegler',
#         'sid', 'hani', 'webber', 'wentzel', 'garyn', 'rapson', 'malatsi',
#         'solly', 'antónio', 'thameena', 'alexforbes', 'thulas', 'nxesi',
#         'bheki', 'cele', 'pandor', 'naledi', 'rights', 'terror', 'act',
#         'fundamental', 'wcg', 'wesgro', 'bernadette', 'girette', 'major',
#         'dilo', 'tse', 'dan', 'piet', 'moselakwe', 'wiersma', 'basson',
#         'adriaan', 'onthatile', 'gladys', 'hattingh', 'lehlogonolo',
#         'sourcefit', 'fumio', 'rishi', 'volodymyr', 'sunak', 'valda',
#         'zelensky', 'kishida', 'kalnina', 'lamola', 'ronald',
#         'khayelitsha', 'percy', 'kruger', 'gate', 'alexandra', 'seretlo',
#         'sharon', 'mantashe', 'gwede', 'mmemme', 'wille', 'sisi',
#         'derek', 'khampepe', 'hlabisa', 'velenkosini', 'sona', 'pillay',
#         'mashatile', 'jean', 'lood', 'jager', 'kleyn', 'paoli',
#         'johnathan', 'bok', 'tk', 'nciza', 'musa', 'gossipmonger',
#         'khawula', 'xolile', 'hridoy', 'towhid', 'anrich', 'nortje',
#         'jeffrey', 'phasha', 'mohammad', 'rishad', 'roland', 'sinner',
#         'taskin', 'zverev', 'jannik', 'garros', 'heindrich', 'alexander',
#         'hossain', 'ahmed', 'klassen', 'twerka', 'kholofelo', 'mathato',
#         'religious', 'disease', 'scientific', 'research', 'carlos',
#         'david', 'cholota', 'ms', 'kurt', 'lee', 'arendse', 'economic',
#         'sector', 'erin', 'ace', 'magudumana', 'nandipha',
#         'sepitlaoptom', 'lolobee', 'hendricks', 'ganief', 'shein',
#         'temu', 'kitshoff', 'moodie', 'jaden', 'hendrikse', 'damien',
#         'willemse', 'canan', 'steven', 'grant', 'sizwe', 'tania',
#         'matshela', 'sithole', 'nunu', 'sande', 'mzwakhe', 'mbuli',
#         'cupido', 'ernst', 'lehlohonolo', 'middendorp', 'seema',
#         'williams', 'keswa', 'gupta', 'ajay', 'vamos', 'barkhuizen',
#         'theunissen', 'benny', 'gantz', 'isaac', 'anthony', 'netanyahu',
#         'michael', 'benni', 'amakhosi', 'fikile', 'mbalula', 'adith',
#         'whitehead', 'tusk', 'wolfson', 'mckenzie', 'bester', 'hippo',
#         'lonehill', 'koppie', 'nadeem', 'facility', 'mandela', 'nelson',
#         'scholz', 'olaf', 'richard', 'mathabatha', 'emmanuel', 'linda',
#         'smotrich', 'junior', 'mdluli', 'wenger', 'de', 'schauffele',
#         'https', 'marikana', 'eipgdydxtr', 'co', 'veld', 'anwar',
#         'kotze', 'george', 'lukas', 'dladlu', 'enzokhule', 'mkp',
#         'chuene', 'laconco', 'liz', 'lejoy', 'lethabo', 'road',
#         'stockville', 'mahmudullah', 'guterres', 'dhansay', 'liebenberg',
#         'mzuzu', 'hugo', 'paul', 'cosatu', 'gallo', 'images', 'lebohang',
#         'christall', 'kay', 'sakib', 'hasan', 'mogotsi', 'greenfield',
#         'thomas', 'mlindelimm', 'masiapato', 'benjamin', 'loftus',
#         'celimpilo', 'jabulani', 'macron', 'gosiame', 'lilongwe',
#         'miller', 'alcaraz', 'retirement', 'legislation', 'abrahams',
#         'magashule', 'aslan', 'joe', 'denny', 'mangena', 'mpho',
#         'leinster', 'aiden', 'markram', 'koko', 'gerda', 'cloete',
#         'versfeld', 'klaasen', 'heinrich', 'chauke', 'procedure',
#         'treatment', 'nonku', 'bush', 'letoya', 'makhene', 'khumalo',
#         'boesak', 'allan', 'erasmus', 'rassie', 'julius', 'profession',
#         'medical', 'cheslin', 'etat', 'coup', 'floyd', 'systems',
#         'belief', 'gianni', 'ramp', 'transaction', 'jama', 'ah', 'chris',
#         'biden', 'celebrity', 'keshav', 'broos', 'immigration', 'al',
#         'lazarus', 'tebas', 'javier', 'raymond', 'discrimination',
#         'exchange', 'market', 'chilima', 'jacob', 'gumede', 'lebo',
#         'values', 'religion', 'shivambu', 'zondo', 'judiciary', 'steyn',
#         'kolbe', 'bafana', 'chakwera', 'malema', 'environmental',
#         'pollution', 'vinicius', 'klaus', 'armed', 'information',
#         'maharaj', 'infantino', 'cyril', 'unrest', 'civil', 'school',
#         'education', 'zuma', 'massacre', 'saulos', 'response',
#         'enforcement', 'nature', 'social', 'condition', 'competition',
#         'discipline', 'employment', 'accomplishment', 'engineering',
#         'science', 'event', 'communities', 'lifestyle', 'media',
#           3.23736856,  3.30686811,  3.37948317,  3.38040622,  3.40032141,
#           3.52288815,  3.55633152,  3.83695502,  3.83695502,  3.93442996,
#           3.93442996,  3.97878937,  4.0590087 ,  4.10354441,  4.14702274,
#           4.37065547,  4.65011442,  4.83086754,  5.1357753 ,  5.28082355,
#           5.28082355,  5.47889405,  5.687062  ,  5.82943658,  6.11055358,
#           6.57480476,  6.61717661,  6.98992282,  7.22435726,  7.40557204,
#           7.42153439,  7.45912748,  7.78437124,  7.86327447,  8.14702135,
#           8.17357794,  8.75754268,  9.90715716, 11.18283826, 11.20723796,
#          11.22471218, 11.46478808, 11.57510333, 11.73292686, 11.73292686,
#          11.82088836, 12.23043385, 12.23043385, 12.23155158, 13.10273826,
#          14.67627987, 15.12569006, 15.65420691, 16.62011788, 17.18731639,
#          17.77310849, 18.79321292, 18.79321292, 19.24953107, 19.24953107,
#          19.70523194, 20.40172538, 22.64961666, 24.5552006 , 26.980103  ,
#          27.62356694, 30.44674785, 38.07816232, 48.2550958 , 53.30092258,
#          93.59155417, 93.59155417]]))]

# %%
# Out:
#     Article_Date_Published                                       Article_Body  \
# 0           6/11/2024 7:34  Reading Time: 3 minutes\nIsrael’s parliament m...
# 1           6/11/2024 5:10  ANC’s aggrieved PEC members draw a line in the...
# 2           6/11/2024 5:00  Daily news update: Axed MK founder alone at Pa...
# 3           6/11/2024 4:52  Search continues for plane carrying Malawi VP ...
# 4           6/11/2024 4:40  Axing corrupt Tshwane cops: ‘more action neede...
# ..                     ...                                                ...
# 195        6/10/2024 19:37  In a distressing development, a military aircr...
# 196        6/10/2024 19:35  The City of Tshwane says it will implement loa...
# 197        6/10/2024 19:35  Chief justice Raymond Zondo has declared June ...
# 198        6/10/2024 19:32  The Department of Transport says it is on trac...
# 199        6/10/2024 19:31  Economic Freedom Fighters (EFF) leader Julius ...
#
#                        Article_Content_People_AI_Model  \
# 0    Benny Gantz|Benjamin Netanyahu|Yoav Gallant|Ga...
# 1    Mathabatha|Stan Mathabatha|Reuben Madadzhe|Reg...
# 2    Axed MK|Jabulani Khumalo|Ajay Gupta|Lethabo Le...
# 3    Saulos Chilima|Saulos Klaus|Saulos Klaus|Valen...
# 4    Axing|Nigel Sibanda/|Grandi Theunissen|Jaco Ba...
# ..                                                 ...
# 195  Saulos Chilima|Saulos Chilima|Lazarus Chakwera...
# 196                 Lindela Mashigo|eNCA|Lehakwe Tlali
# 197                                Raymond Zondo|Zondo
# 198             Gemalto Altron Fintech Southern Africa
# 199  Julius Malema|Twerka|Julius Malema|Julius Male...
#
#                      Article_Content_Entities_AI_Model      Article_Source  \
# 0    Knesset|Gantz|Defence|Gantz|Resented|the Israe...        sabcnews.com
# 1    ANC|PEC|Limpopo ANC|ANC|PEC|the Electoral Comm...       citizen.co.za
# 2    Parliament | SA|| Court|Ace’s|WeSizwe party|MK...       citizen.co.za
# 3    Office of the President|Cabinet|the Malawi Def...       citizen.co.za
# 4    TMPD|Department|Tshwane Metro Police Departmen...       citizen.co.za
# ..                                                 ...                 ...
# 195                               Malawi Defense Force     surgezirc.co.za
# 196                                Soweto Gospel Choir       news365.co.za
# 197  the National Assembly|the National Council of ...  businesslive.co.za
# 198  The Department of Transport|Cabinet|SCM|Corpor...     economy24.co.za
# 199  EFF|Shebeshxt|Shebeshxt|Briefly TV Life|Shebes...       briefly.co.za
#
#                   Voice                            Article_Themes_AI_Model  \
# 0                   NaN  [Primary: Conflict, war and peace|92% |Seconda...
# 1    Alex Japho Matlala  [Primary: Society|67% |Secondary: Uncategorize...
# 2         Nicholas Zaal  [Primary: Economy, business and finance|51% |S...
# 3          Faizel Patel  [Primary: Politics|52% |Secondary: Uncategoriz...
# 4       Marizka Coetzer  [Primary: Crime, law and justice|100% |Seconda...
# ..                  ...                                                ...
# 195                 NaN  [Primary: Politics|80% |Secondary: Uncategoriz...
# 196        Nelly Ndlovu  [Primary: Economy, business and finance|95% |S...
# 197                 NaN  [Primary: Politics|94% |Secondary: Government ...
# 198                 NaN  [Primary: Economy, business and finance|82% |S...
# 199       Jessica Gcaba  [Primary: Disaster, accident and emergency inc...
#
#       Article_Subject_Keyword_Identified  \
# 0                                    NaN
# 1                                    ANC
# 2    Cape Town|Johannesburg|South Africa
# 3                                    NaN
# 4                           South Africa
# ..                                   ...
# 195                                   DA
# 196                         South Africa
# 197                               ANC|DA
# 198                         South Africa
# 199                    EFF|Julius Malema
#
#                       Article_Topic_Keyword_Identified  \
# 0      Armed Conflict|Crime & Terrorism|State Security
# 1                                                  NaN
# 2    Armed Conflict|Civil Unrest & Protest|Crime & ...
# 3                                       State Security
# 4                     Crime & Terrorism|State Security
# ..                                                 ...
# 195                                     State Security
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                Leadership delivery
#
#                                         Combined_Names  \
# 0    Benny Gantz|Benjamin Netanyahu|Yoav Gallant|Ga...
# 1    Mathabatha|Stan Mathabatha|Reuben Madadzhe|Reg...
# 2    Axed MK|Jabulani Khumalo|Ajay Gupta|Lethabo Le...
# 3    Saulos Chilima|Saulos Klaus|Saulos Klaus|Valen...
# 4    Axing|Nigel Sibanda/|Grandi Theunissen|Jaco Ba...
# ..                                                 ...
# 195  Saulos Chilima|Saulos Chilima|Lazarus Chakwera...
# 196  Lindela Mashigo|eNCA|Lehakwe Tlali Soweto Gosp...
# 197  Raymond Zondo|Zondo the National Assembly|the ...
# 198  Gemalto Altron Fintech Southern Africa The Dep...
# 199  Julius Malema|Twerka|Julius Malema|Julius Male...
#
#                                        Processed_Names
# 0    benny gantz benjamin netanyahu yoav gallant ga...
# 1    mathabatha stan mathabatha reuben madadzhe reg...
# 2    axed mk jabulani khumalo ajay gupta lethabo le...
# 3    saulos chilima saulos klaus saulos klaus valen...
# 4    axing nigel sibanda grandi theunissen jaco bar...
# ..                                                 ...
# 195  saulos chilima saulos chilima lazarus chakwera...
# 196  lindela mashigo enca lehakwe tlali soweto gosp...
# 197  raymond zondo zondo national assembly national...
# 198  gemalto altron fintech southern africa departm...
# 199  julius malema twerka julius malema julius male...
#
# [200 rows x 11 columns]
