# %%
import pandas as pd
import numpy as np

#read in the dataset with the new columns given to us
df = pd.read_csv('new_data.csv')

#create a new empty dataset to add
df_new = pd.DataFrame(columns=df.columns)
#the column with the name or entity name
df_new.rename(columns={'Article_Content_People_AI_Model': 'Name'}, inplace=True)
#the type, either people or entity
df_new.rename(columns={'Article_Content_Entities_AI_Model': 'Identity_Type'}, inplace=True)
#new column with the position of the name relative to the others in the article
df_new['Position'] = np.nan
#new column with the article associated
df_new['Article'] = np.nan
# Out:
# /Applications/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
#create a subset of the data - this is what to change to use other parts of the dataset
subset = df[:1000]

# %%
subset.columns
# Out:
# Index(['Article_Date_Published', 'Article_Body',
#        'Article_Content_People_AI_Model', 'Article_Content_Entities_AI_Model',
#        'Article_Source', 'Voice', 'Article_Themes_AI_Model',
#        'Article_Subject_Keyword_Identified',
#        'Article_Topic_Keyword_Identified'],
#       dtype='object')

# %%
#separate the strings into arrays
for num in range(0, len(subset)):
    subset.at[num, 'Article_Content_People_AI_Model'] = str(subset['Article_Content_People_AI_Model'][num]).split("|")
    subset.at[num, 'Article_Content_Entities_AI_Model'] = str(subset['Article_Content_Entities_AI_Model'][num]).split("|")
    subset.at[num, 'Article_Subject_Keyword_Identified'] = str(subset['Article_Subject_Keyword_Identified'][num]).split("|")
    subset.at[num, 'Article_Topic_Keyword_Identified'] = str(subset['Article_Topic_Keyword_Identified'][num]).split("|")

# %%
#add the people names
newdf_counter = 0
olddf_counter = -1
article_counter = 0
for entry in subset['Article_Content_People_AI_Model']:
    olddf_counter+=1
    position_counter = 0
    for word in entry:
        df_new.loc[newdf_counter, 'Name'] = word
        df_new.loc[newdf_counter, 'Identity_Type'] = 'People'
        df_new.loc[newdf_counter, 'Position'] = position_counter
        df_new.loc[newdf_counter, 'Article'] = article_counter
        df_new.loc[newdf_counter, 'Article_Date_Published'] = subset.loc[olddf_counter, 'Article_Date_Published']
        df_new.loc[newdf_counter, 'Article_Body'] = subset.loc[olddf_counter, 'Article_Body']
        df_new.loc[newdf_counter, 'Article_Source'] = subset.loc[olddf_counter, 'Article_Source']
        df_new.loc[newdf_counter, 'Voice'] = subset.loc[olddf_counter, 'Voice']
        df_new.loc[newdf_counter, 'Article_Themes_AI_Model'] = subset.loc[olddf_counter, 'Article_Themes_AI_Model']
        df_new.at[newdf_counter, 'Article_Subject_Keyword_Identified'] = subset.at[olddf_counter, 'Article_Subject_Keyword_Identified']
        df_new.at[newdf_counter, 'Article_Topic_Keyword_Identified'] = subset.at[olddf_counter, 'Article_Topic_Keyword_Identified']
        newdf_counter+=1
        position_counter+=1
    article_counter+=1

# %%
#add the entity names
newdf_counter = len(df_new)
olddf_counter = -1
article_counter = 0
for entry in subset['Article_Content_Entities_AI_Model']:
    olddf_counter+=1
    position_counter = 0
    for word in entry:
        df_new.loc[newdf_counter, 'Name'] = word
        df_new.loc[newdf_counter, 'Identity_Type'] = 'Entity'
        df_new.loc[newdf_counter, 'Position'] = position_counter
        df_new.loc[newdf_counter, 'Article'] = article_counter
        df_new.loc[newdf_counter, 'Article_Date_Published'] = subset.loc[olddf_counter, 'Article_Date_Published']
        df_new.loc[newdf_counter, 'Article_Body'] = subset.loc[olddf_counter, 'Article_Body']
        df_new.loc[newdf_counter, 'Article_Source'] = subset.loc[olddf_counter, 'Article_Source']
        df_new.loc[newdf_counter, 'Voice'] = subset.loc[olddf_counter, 'Voice']
        df_new.loc[newdf_counter, 'Article_Themes_AI_Model'] = subset.loc[olddf_counter, 'Article_Themes_AI_Model']
        df_new.at[newdf_counter, 'Article_Subject_Keyword_Identified'] = subset.at[olddf_counter, 'Article_Subject_Keyword_Identified']
        df_new.at[newdf_counter, 'Article_Topic_Keyword_Identified'] = subset.at[olddf_counter, 'Article_Topic_Keyword_Identified']
        newdf_counter+=1
        position_counter+=1
    article_counter+=1

# %%
df_new.head(50)
# Out:
#    Article_Date_Published                                       Article_Body  \
# 0            6/11/24 7:34  Reading Time: 3 minutes\nIsrael’s parliament m...
# 1            6/11/24 7:34  Reading Time: 3 minutes\nIsrael’s parliament m...
# 2            6/11/24 7:34  Reading Time: 3 minutes\nIsrael’s parliament m...
# 3            6/11/24 7:34  Reading Time: 3 minutes\nIsrael’s parliament m...
# 4            6/11/24 7:34  Reading Time: 3 minutes\nIsrael’s parliament m...
# 5            6/11/24 7:34  Reading Time: 3 minutes\nIsrael’s parliament m...
# 6            6/11/24 7:34  Reading Time: 3 minutes\nIsrael’s parliament m...
# 7            6/11/24 7:34  Reading Time: 3 minutes\nIsrael’s parliament m...
# 8            6/11/24 7:34  Reading Time: 3 minutes\nIsrael’s parliament m...
# 9            6/11/24 5:10  ANC’s aggrieved PEC members draw a line in the...
# 10           6/11/24 5:10  ANC’s aggrieved PEC members draw a line in the...
# 11           6/11/24 5:10  ANC’s aggrieved PEC members draw a line in the...
# 12           6/11/24 5:10  ANC’s aggrieved PEC members draw a line in the...
# 13           6/11/24 5:10  ANC’s aggrieved PEC members draw a line in the...
# 14           6/11/24 5:10  ANC’s aggrieved PEC members draw a line in the...
# 15           6/11/24 5:10  ANC’s aggrieved PEC members draw a line in the...
# 16           6/11/24 5:10  ANC’s aggrieved PEC members draw a line in the...
# 17           6/11/24 5:10  ANC’s aggrieved PEC members draw a line in the...
# 18           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 19           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 20           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 21           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 22           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 23           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 24           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 25           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 26           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 27           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 28           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 29           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 30           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 31           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 32           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 33           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 34           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 35           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 36           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 37           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 38           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 39           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 40           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 41           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 42           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 43           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 44           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 45           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 46           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 47           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 48           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
# 49           6/11/24 5:00  Daily news update: Axed MK founder alone at Pa...
#
#                         Name Identity_Type Article_Source               Voice  \
# 0                Benny Gantz        People   sabcnews.com                 NaN
# 1         Benjamin Netanyahu        People   sabcnews.com                 NaN
# 2               Yoav Gallant        People   sabcnews.com                 NaN
# 3              Gadi Eisenkot        People   sabcnews.com                 NaN
# 4           Bezalel Smotrich        People   sabcnews.com                 NaN
# 5              Assaf Shapira        People   sabcnews.com                 NaN
# 6                Inbal Tzach        People   sabcnews.com                 NaN
# 7                 Tal Shoham        People   sabcnews.com                 NaN
# 8                   Smotrich        People   sabcnews.com                 NaN
# 9                 Mathabatha        People  citizen.co.za  Alex Japho Matlala
# 10           Stan Mathabatha        People  citizen.co.za  Alex Japho Matlala
# 11           Reuben Madadzhe        People  citizen.co.za  Alex Japho Matlala
# 12          Reggie Molokomme        People  citizen.co.za  Alex Japho Matlala
# 13              Danny Ndlovu        People  citizen.co.za  Alex Japho Matlala
# 14             Frans Mokwele        People  citizen.co.za  Alex Japho Matlala
# 15           Rosemary Molepo        People  citizen.co.za  Alex Japho Matlala
# 16          Jeremiah Ngobeni        People  citizen.co.za  Alex Japho Matlala
# 17             Jimmy Machaka        People  citizen.co.za  Alex Japho Matlala
# 18                   Axed MK        People  citizen.co.za       Nicholas Zaal
# 19          Jabulani Khumalo        People  citizen.co.za       Nicholas Zaal
# 20                Ajay Gupta        People  citizen.co.za       Nicholas Zaal
# 21             Lethabo Lejoy        People  citizen.co.za       Nicholas Zaal
# 22             Christall Kay        People  citizen.co.za       Nicholas Zaal
# 23          Jabulani Khumalo        People  citizen.co.za       Nicholas Zaal
# 24          Jabulani Khumalo        People  citizen.co.za       Nicholas Zaal
#